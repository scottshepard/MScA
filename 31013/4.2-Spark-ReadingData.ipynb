# %% [markdown]
# # Big Data Platforms
#
# ## Spark RDD
#
# Author: Ashish Pujari (apujari@uchicago.edu)

# %%
#import statements
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('TestApp').getOrCreate()
sc = spark.sparkContext

# %%
# %time data = sc.textFile("T:\\courses\\BigData\\data\\chicago-food-inspections\\food-inspections.csv")
# Out:
# Wall time: 748 ms

# %% [markdown]
# ### Action vs Transformation
#
# Actual (distributed) computations in Spark take place when we execute actions and not transformations. In this case count is the action we execute on the RDD. We can apply as many transformations as we want on a our RDD and no computation will take place until we call the first action that, in this case takes a few seconds to complete

# %%
#Total Record Count
# %time data.count()
# Out:
# Wall time: 5.1 s
# 178090

# %% [markdown]
# ### Map Transformation
#
# By using the map transformation in Spark, we can apply a function to every element in our RDD. Python's lambdas are specially expressive for this particular. In this case we want to read our data file as a CSV formatted one. We can do this by applying a lambda function to each element in the RDD as follows.

# %%
csv_data = data.map(lambda x: x.split(","))
head_rows = csv_data.take(5)

#print header row
print(head_rows[0])
# Out:
# ['Inspection ID', 'DBA Name', 'AKA Name', 'License #', 'Facility Type', 'Risk', 'Address', 'City', 'State', 'Zip', 'Inspection Date', 'Inspection Type', 'Results', 'Violations', 'Latitude', 'Longitude', 'Location']

# %%
def parseLine(line):
    elems = line.split(",")
    tag = elems[15]
    return (tag, elems)

# %time key_csv_data = data.map(parseLine)
# %time head_rows = key_csv_data.take(5)
print(head_rows[0])
# Out:
# Wall time: 0 ns
# Wall time: 517 ms
# ('Longitude', ['Inspection ID', 'DBA Name', 'AKA Name', 'License #', 'Facility Type', 'Risk', 'Address', 'City', 'State', 'Zip', 'Inspection Date', 'Inspection Type', 'Results', 'Violations', 'Latitude', 'Longitude', 'Location'])

# %% [markdown]
# ### Collect Action

# %%
# %time head_rows = csv_data.take(1000)
# Out:
# Wall time: 894 ms

# %%
#might time out or run out of memory on smaller machine  
# %time all_data = data.collect()
# Out:
# Wall time: 4.93 s

# %%
all_data[0:10]
# Out:
# ['Inspection ID,DBA Name,AKA Name,License #,Facility Type,Risk,Address,City,State,Zip,Inspection Date,Inspection Type,Results,Violations,Latitude,Longitude,Location',
#  '2240307,2 POTZ & A PAN EATERY,2 POTZ & A PAN EATERY,2626283,Restaurant,Risk 1 (High),6052 S EBERHART AVE ,CHICAGO,IL,60637,2018-11-16T00:00:00,License,Pass w/ Conditions,"3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: OBSERVED NO EMPLOYEE HEALTH POLICY AVAILABLE. INSTRUCTED MANAGER TO PROVIDE EMPLOYEE HEALTH POLICY. PRIORITY FOUNDATION 7-38-012(A) | 5. PROCEDURES FOR RESPONDING TO VOMITING AND DIARRHEAL EVENTS - Comments: OBSERVED NO CLEAN UP POLICY FOR VOMITING OR DIARRHEAL EVENTS. INSTRUCTED MANAGER TO PROVIDE CLEAN UP POLICY. PRIORITY FOUNDATION 7-38-005 | 10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE - Comments: OBSERVED NO HAND WASHING SIGNS AT HAND WASHING SINKS IN PREP AND WASHROOM AREAS. INSTRUCTED MANAGER TO PROVIDE HAND WASHING SIGNS AT ALL HAND WASHING SINKS USED BY EMPLOYEES. | 38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments: OBSERVED 1/4\' GAP ON BOTTOM OF FRONT ENTRANCE/EXIT DOOR. INSTRUCTED MANAGER TO SEAL ALL OUTER OPENINGS ON DOOR TO PREVENT PEST ENTRY. | 57. ALL FOOD EMPLOYEES HAVE FOOD HANDLER TRAINING - Comments: OBSERVED NO FOOD HANDLER TRAINING. MUST PROVIDE FOOD HANDLER TRAINING FOR ALL EMPLOYEES. | 58. ALLERGEN TRAINING AS REQUIRED - Comments: OBSERVED NO ALLERGEN TRAINING AVAILABLE. ALL CERTIFIED MANAGER MUST PROVIDE ALLERGEN TRAINING.",41.78418310620243,-87.61338492635632,"{\'longitude\': \'-87.61338492635632\', \'needs_recoding\': False, \'latitude\': \'41.78418310620243\'}"',
#  '2240303,"CREMERIA SANTA MARIA, INC",CREMERIA SANTA MARIA,1868311,Grocery Store,Risk 1 (High),3424 W 26TH ST ,CHICAGO,IL,60623,2018-11-16T00:00:00,Canvass Re-Inspection,Pass w/ Conditions,"3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: OBSERVED NO EMPLOYEES HEALTH POLICY.MUST PROVIDE AND MAINTAIN.(PRIORITY FOUNDATION - NO CITATION ISSUED",41.84454429200885,-87.71107279676545,"{\'longitude\': \'-87.71107279676545\', \'needs_recoding\': False, \'latitude\': \'41.84454429200885\'}"',
#  '2240297,ORALE,ORALE,2631871,Restaurant,Risk 1 (High),1623 W 43rd ST ,CHICAGO,IL,60609,2018-11-16T00:00:00,License,Pass w/ Conditions,"3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: No employee health policy on site. Must provide. Priority foundation violation 7-38-10 | 5. PROCEDURES FOR RESPONDING TO VOMITING AND DIARRHEAL EVENTS - Comments: No vomit and diarrhea policy on site. Must provide. Priority foundation violation 7038-005. | 10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE - Comments: Must provide proper hand washing signage in plain view of exposed hand washing sinks.  | 25. CONSUMER ADVISORY PROVIDED FOR RAW/UNDERCOOKED FOOD - Comments: Observed menu contains disclosure but not reminder. Explained must provide reminder (asterisk) for all undercooked animal products on the menu (such as eggs in breakfast items). Priority foundation 7-38-005. | 51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICES - Comments: Back flow prevention device not located on rear utility sink. Must provide location. Must maintain same.  | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: Observed excessive debris on floors throughout rear storage room and behind equipment. Must detail clean and sanitize floors. Must maintain same.  | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: Observed excessive clutter in rear storage room (equipment not in use). Must remove all unnecessary or not in use equipment. Must clean and maintain an organized rear storage room.  | 58. ALLERGEN TRAINING AS REQUIRED - Comments: All food sanitation managers must obtain proof of allergen training. ",41.81574727482529,-87.66621797293804,"{\'longitude\': \'-87.66621797293804\', \'needs_recoding\': False, \'latitude\': \'41.81574727482529\'}"',
#  '2240300,AMAZING GRACE DAYCARE CENTER,AMAZING GRACE DAYCARE CENTER,2215901,Daycare Above and Under 2 Years,Risk 1 (High),11123-11125 S HALSTED ST ,CHICAGO,IL,60628,2018-11-16T00:00:00,Canvass,Pass w/ Conditions,"3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: OBSERVED NO EMPLOYEE HEALTH POLICY ON SITE. INSTRUCTED TO IMPLEMENT A POLICY WHERE ALL MANAGERS, FOOD AND CONDITIONAL EMPLOYEES ACKNOWLEDGES THEIR RESPONSIBILITIES IN REPORTING ANY ILLNESSES THEY MAY INCUR THAT IS TRANSMISSIBLE THROUGH FOOD. PRIORITY FOUNDATION VIOLATION 7-38-012 NO CITATION ISSUED | 5. PROCEDURES FOR RESPONDING TO VOMITING AND DIARRHEAL EVENTS - Comments: OBSERVED NO PROCEDURES FOR RESPONDING TO VOMITING AND DIARRHEAL EVENTS ON SITE. INSTRUCTED TO IMPLEMENT A PROCEDURE AND PROVIDE ALL NECESSARY SUPPIES TO HANDLE SUCH EVENTS. PRIORITY FOUNDATION VIOLATION 7-38-005 NO CITATION ISSUED | 10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE - Comments: OBSERVED NO HANDWASHING SIGNAGE OR POSTERS AT NONE OF THE HAND WASHING SINKS. INSTRUCTED TO PROVIDE HANDWASHING SIGNS TO ALL HAND WASHING SINKS. MAINTAIN SAME. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: WATER STAINED CEILING TILES IN THE REAR ADULT TOILET ROOM IN THE INFANT\'S ROOM. INSTRUCTED TO REPLACE.  6-501.114 CLUTTER IN THE STORAGE AND CLASSROOMS. INSTRUCTED TO ELIMINATE CLUTTER, REMOVE ALL UNNECESSARY ITEMS AND ORGANIZE ALL AREAS.  6-501.13 INSTRUCTED TO CLEAN AND MAINTAIN FLOORS IN ALL CORNERS AND UNDER/AROUND ALL HEAVY EQUIPMENT TO REMOVE ALL DIRT AND DEBRIS.  ",41.69164609748754,-87.6422140544927,"{\'longitude\': \'-87.6422140544927\', \'needs_recoding\': False, \'latitude\': \'41.69164609748754\'}"',
#  '2240286,JOYS,JOYS,1677471,Restaurant,Risk 1 (High),3257-3259 N BROADWAY ,CHICAGO,IL,60657,2018-11-16T00:00:00,Suspected Food Poisoning,Pass w/ Conditions,"3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments:  2-102.14(N) FOUND NO EMPLOYEE HEALTH POLICY AT PREMISES. PRIORITY FOUNDATION. NO CITATION ISSUED. 7-38-010. MUST PROVIDE. | 5. PROCEDURES FOR RESPONDING TO VOMITING AND DIARRHEAL EVENTS - Comments: 2-501.11 FOUND NO VOMIT AND DIARRHEAL CLEAN UP PROCEDURE. PRIORITY FOUNDATION. NO CITATION ISSUED. 7-38-005. MUST PROVIDE. | 57. ALL FOOD EMPLOYEES HAVE FOOD HANDLER TRAINING - Comments: FOUND FOODHANDLERS WITH NO FOODHANDER TRAINING CERTIFICATES. MUST OBTAIN | 58. ALLERGEN TRAINING AS REQUIRED - Comments: FOUND FOOD SANITATION MANAGERS WITH NO ALLERGEN TRAINING. MUST OBTAIN. ",41.94171290343118,-87.64430633617879,"{\'longitude\': \'-87.64430633617879\', \'needs_recoding\': False, \'latitude\': \'41.94171290343118\'}"',
#  '2240281,ZAIQA RESTAURANT,ZAIQA RESTAURANT,2632018,Restaurant,Risk 1 (High),2245 W DEVON AVE ,CHICAGO,IL,60659,2018-11-16T00:00:00,License,Pass w/ Conditions,"3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: NO WRITTEN EMPLOYEE HEALTH POLICY. MUST PROVIDE. PRIORITY FOUNDATION VIOLATION. NO CITATION ISSUED. | 5. PROCEDURES FOR RESPONDING TO VOMITING AND DIARRHEAL EVENTS - Comments: NO WRITTEN PROCEDURE OR REQUIRED EQUIPMENT FOR A VOMITING OR DIARRHEA EVENT. MUST PROVIDE. PRIORITY FOUNDATION VIOLATION. NO CITATION ISSUED. | 33. PROPER COOLING METHODS USED; ADEQUATE EQUIPMENT FOR TEMPERATURE CONTROL - Comments: FRONT FOOD DISPLAY COOLER FOUND WITH A TEMPERATURE OF 46F. COOLER TAGGED HELD FOR INSPECTION AND MUST NOT USE UNTIL REPAIRED AND MAINTAINS A TEMPERATURE OF 41F OR BELOW, CDPH CONTACTED FOR RE-INSPECTION AND TAG REMOVAL. PRIORITY VIOLATION. NO CITATION ISSUED. | 38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments: FRONT DOUBLE DOOR EXIT DOOR FOUND WITH OPEN 1/2 INCH GAP ON THE BOTTOM, BETWEEN THE TWO DOORS  MAKING THEM NOT RODENT PROOF OR TIGHT FITTING. MUST PROVIDE A TIGHT FITTING SEAL ON THE BOTTOM THRESHOLD OF THE DOOR. | 39. CONTAMINATION PREVENTED DURING FOOD PREPARATION, STORAGE & DISPLAY - Comments: MISSING SPLASH GUARDS ON BOTH SIDES OF THE HAND SINK LOCATED BETWEEN THE THREE COMPARTMENT SINK AND THE GAS COOKING STOVE. MUST PROVIDE. | 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: RAW WOODEN TWO BY FOUR USED AS SUPPORT, LOCATED BEHIND THE COOKS LINE OF THE WALL AND GAS PIPING MUST BE REMOVED. | 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: TORN RUBBER DOOR GASKET ON THE THREE DOOR REACH-IN COOLER. MUST REPLACE. INOPERABLE/BROKEN ATTACHED SINK STOPPERS AT THE THREE COMPARTMENT SINK. MUST REPAIR OR PROVIDE PROPER SINK STOPPERS. | 49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: MUST NOT USE TINFOIL AS LINER FOR SHELVING THE THE FOOD PREP AREAS.----METAL RACK SHELVING THROUGHOUT THE WALK-IN COOLER FOUND WITH EXCESSIVE RUST AND ENCRUSTED FOOD DEBRIS. MUST REMOVE RUST AND FOOD DEBRIS.----INTERIOR OF THE THREE DOOR REACH-IN COOLER WITH FOOD SPILLAGE. MUST CLEAN AND MAINTAIN. | 51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICES - Comments: BACK FLOW PREVENTOR NOT LOCATED TO BE SERVICED OR MAINTAINED AT THE UTILITY MOP SINK OR THE THREADED HOSE BIB PROTRUDING FROM THE WALL VENT IN THE TOILET ROOM. MUST PROVIDE BACK FLOW PREVENTION DEVICES. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: EXCESSIVE DUST ON THE CEILING VENTS IN THE TOILET ROOMS. MUST CLEAN AND MAINTAIN. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: HOLE IN THE METAL WALL ON THE GAS STOVE COOKS LINE. HOLES IN THE BASEBOARDS AT THE ENTRANCE TO THE NORTH TOILET ROOM. MUST SEAL ALL. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: INOPERABLE UNUSED COOLER MUST BE REPAIRED OR REMOVED FROM THE PREMISES. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: TAPE BEING USED AS A MEANS OF REPAIR ON THE METAL WALLS INSIDE THE WALK-IN COOLER, AT THE REAR FOOD PREP AND ALONG ALL BASEBOARDS. MUST REMOVE ALL TAPE AND PROVIDE A SMOOTH CLEANABLE SURFACE. | 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: MISSING LIGHT SHIELD THROUGHOUT THE FOOD PREP AREAS. MUST PROVIDE LIGHT SHIELDS. | 58. ALLERGEN TRAINING AS REQUIRED - Comments: NO PROOF OF TRAINING OR CERTIFICATE AVAILABLE FOR THE PENDING CITY OF CHICAGO CERTIFIED FOOD MANAGER. MUST PROVIDE.",41.9976744700477,-87.6867563084304,"{\'longitude\': \'-87.6867563084304\', \'needs_recoding\': False, \'latitude\': \'41.9976744700477\'}"',
#  '2240284,RAYITO DE SOL SPANISH IMMERSION EARLY LEARNING CEN,RAYITO DE SOL SPANISH IMMERSION EARLY LEARNING CEN,2600725,Children\'s Services Facility,Risk 1 (High),2550 W ADDISON ST ,CHICAGO,IL,60618,2018-11-16T00:00:00,License Re-Inspection,Pass w/ Conditions,"3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: 2-102.14(N)-NO EMPLOYEE HEALTH POLICY. INSTRUCTED TO PROVIDE. PRIORITY FOUNDATION 7-38-010 NO CITATION ISSUED. | 5. PROCEDURES FOR RESPONDING TO VOMITING AND DIARRHEAL EVENTS - Comments: 2-501.11-NO CLEAN UP PROCEDURE FOR VOMITING AND DIARRHEA. INSTRUCTED TO PROVIDE CLEAN UP PROCEDURE. PRIORITY FOUNDATION 7-38-005 NO CITATION ISSUED.  | 41. WIPING CLOTHS: PROPERLY USED & STORED - Comments: 3-304.14-WIPING CLOTH FOR WIPING THE PREP TABLES, COOLERS MUST BE STORED ON A BUCKET WITH SANITIZING SOLUTION.",41.94682721814422,-87.69268373740718,"{\'longitude\': \'-87.69268373740718\', \'needs_recoding\': False, \'latitude\': \'41.94682721814422\'}"',
#  '2240277,FRESHII,FRESHII,2446395,Restaurant,Risk 1 (High),1166 W MADISON ST ,CHICAGO,IL,60607,2018-11-16T00:00:00,Canvass,Fail,"2. CITY OF CHICAGO FOOD SERVICE SANITATION CERTIFICATE - Comments: NO CERTIFIED MANAGER ON SITE DURING THE INSPECTION, WITH A VALID CERTIFICATE POSTED. INSTRUCTED TO HAVE A CERTIFIED MANAGER ONSITE AT ALL TIMES WHEN TCS FOODS, RICE, MELONS, ETC., ARE BEING PREPARED OR SERVED. PRIORITY FOUNDATION 7-38-012 CITATION ISSUED.  | 3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: NO EMPLOYEE HEALTH POLICY ON-SITE. INSTRUCTED TO PROVIDE THE CITY\'S HEALTH POLICY OR SIMILAR DOCUMENTS USED TO DEMONSTRATE COMPLIANCE. PRIORITY FOUNDATION 7-38-010 NO CITATION ISSUED.  | 5. PROCEDURES FOR RESPONDING TO VOMITING AND DIARRHEAL EVENTS - Comments: NO CLEAN UP PROCEDURES ONSITE FOR DIARRHEA OR VOMITING EVENTS. INSTRUCTED TO PROVIDE KIT & PROCEDURES FOR EMPLOYEES TO FOLLOW. PRIORITY FOUNDATION 7-38-005.  | 23. PROPER DATE MARKING AND DISPOSITION - Comments: OBSERVED NO DATE MARKINGS ON TCS/RTE FOODS IN PREP & WALK COOLERS. INSTRUCTED TO PROVIDE CONSUME BY DATES ON FOOD PREPARED AND STORED IN COOLERS OVER 24 HRS. INSTRUCTED TO MAINTAIN. | 37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER - Comments: MUST PROVIDE ALLERGEN AND INGREDIENT LABELS ON THE CHIA PUDDING BEING SOLD IN THE SELF SERVER COOLER ADJACENT TO THE CASH REGISTER.  PRIORITY FOUNDATION 7-38-005 NO CITATION ISSUED.    3.302.12 MUST LABEL ALL FOOD CONTAINERS WITH COMMON FOOD NAMES, WHEN FOOD HAS BEEN REMOVED FROM ORIGINAL PACKAGING. INSTRUCTED TO MAINTAIN. | 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: MUST DISCONTINUE USING MILK CRATES AS STORAGE RACK FOR EQUIPMENT BEHIND THE FRONT SERVICE COUNTER. INSTRUCTED TO MAINTAIN. | 49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: MUST DETAIL CLEAN DRIED FOOD DEBRIS FROM LOWER SHELVES ON PREP TABLES IN REAR PREP AREA. INSTRUCTED TO MAINTAIN. | 50. HOT & COLD WATER AVAILABLE; ADEQUATE PRESSURE - Comments: OBSERVED NO HOT WATER ON THE PREMISES. INCLUDING 2 HAND SINKS IN PREP AREAS, 3-COMP SINK, OR IN HAND SINKS IN BOTH TOILET ROOMS. EMPLOYEES UNABLE TO WASH HANDS AND UNABLE TO WASH AND RINSE DISHES, PER CITY CODE.  HOT WATER TEMPERATURES RANGE FROM 50F TO 60F. PRIORITY VIOLATION 7-38-030(C) CITATION ISSUED. | 51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICES - Comments: MUST REPAIR LEAKY COLD WATER PIPE AT HAND SINK IN FRONT PREP AREA. INSTRUCTED TO MAINTAIN. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: 6.501.114 MUST REMOVE OR ORGANIZE CLUTTER BEHIND THE FRONT SERVICE COUNTER. ALSO, ORGANIZE CLUTTER IN THE REAR STORAGE ROOM. ELEVATE ITEMS 6\' OFF FLOORS TO PREVENT RODENT HARBORAGE, AND MAINTAIN.   6.201.11 MUST DETAIL CLEAN DEBRIS FROM FLOORS IN THE REAR STORAGE ROOM. INSTRUCTED TO MAINTAIN. | 57. ALL FOOD EMPLOYEES HAVE FOOD HANDLER TRAINING - Comments: FOOD HANDLER REQUIREMENTS NOT MET . INFORMATION PROVIDED. | 58. ALLERGEN TRAINING AS REQUIRED - Comments: ALLERGEN TRAINING IS REQUIRED FOR EMPLOYEES THAT HAVE A CITY OF CHICAGO FOOD SANITATION LICENSE. INSTRUCTED TO COMPLETE TRAINING AND KEEP CERTIFICATE ON-SITE. ",41.881731324473414,-87.65685079354886,"{\'longitude\': \'-87.65685079354886\', \'needs_recoding\': False, \'latitude\': \'41.881731324473414\'}"',
#  '2240275,CHILDREN\'S CENTER INC,CHILDREN\'S CENTER INC,2215544,Daycare Above and Under 2 Years,Risk 1 (High),12801-12803 S HALSTED ST ,CHICAGO,IL,60628,2018-11-16T00:00:00,Canvass,Pass w/ Conditions,"3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: OBSERVED NO EMPLOYEE HEALTH POLICY ON SITE. INSTRUCTED TO IMPLEMENT A POLICY WHERE ALL MANAGERS, FOOD AND CONDITIONAL EMPLOYEES ACKNOWLEDGE THEIR RESPONSIBILITIES IN REPORTING ANY ILLNESSES THEY MAY INCUR THAT ARE TRANSMISSIBLE THROUGH FOOD. PRIORITY FOUNDATION VIOLATION 7-38-012 NO CITATION ISSUED | 5. PROCEDURES FOR RESPONDING TO VOMITING AND DIARRHEAL EVENTS - Comments: OBSERVE NO PROCEDURES FOR RESPONDING TO VOMITING AND DIARRHEAL EVENTS ON SITE. INSTRUCTED TO IMPLEMENT A PROCEDURE AND PROVIDE ALL NECESSARY SUPPLIES FOR HANDLING SUCH EVENTS. PRIORITY FOUNDATION VIOLATION 7-38-005 NO CITATION ISSUED | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: FOUND THE FLOORS IN THE CORNERS AND UNDER/AROUND THE HEAVY EQUIPMENT IN THE KITCHEN AND STORAGE AREAS WITH DIRT/DEBRIS. INSTRUCTED TO CLEAN AND MAINTAIN FLOORS.",41.661326016281905,-87.64121030558698,"{\'longitude\': \'-87.64121030558698\', \'needs_recoding\': False, \'latitude\': \'41.661326016281905\'}"']
