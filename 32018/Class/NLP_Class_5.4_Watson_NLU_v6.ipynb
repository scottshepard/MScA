# %% [markdown]
# ## Natural Language Understanding
# https://natural-language-understanding-demo.mybluemix.net/

# %% [markdown]
# Free 6 months trial for students: https://ibm.onthehub.com and click on "Students".
# Offer includes IBM Cloud as well as Watson services

# %%
#!pip install watson_developer_cloud --upgrade

# %%
import sys
import os
import json
import re
import pandas as pd
sys.path.append(os.path.join(os.getcwd(),'..'))
import watson_developer_cloud
from watson_developer_cloud import NaturalLanguageUnderstandingV1
from watson_developer_cloud.natural_language_understanding_v1 import Features, EntitiesOptions, KeywordsOptions, ConceptsOptions, RelationsOptions, SentimentOptions, SemanticRolesOptions, EmotionOptions, CategoriesOptions

# %%
natural_language_understanding = watson_developer_cloud.NaturalLanguageUnderstandingV1(version='2018-03-16',
                                                            username='user',
                                                            password='pw')

# %% [markdown]
# https://watson-api-explorer.mybluemix.net/apis/natural-language-understanding-v1

# %% [markdown]
# #### Concepts
#
# Identify general concepts that are referenced or alluded to in your content. Concepts that are detected typically have an associated link to a DBpedia resource.
#
# #### Entities
# Detect important people, places, geopolitical entities and other types of entities in your content. Entity detection recognizes consecutive coreferences of each entity. For example, analysis of the following text would count "Barack Obama" and "He" as the same entity:
# "Barack Obama was the 44th President of the United States. He took office in January 2009."
#
# #### Keywords
# Determine the most important keywords in your content. Keyword phrases are organized by relevance in the results.
#
# #### Categories
# Categorize your content into a hierarchical 5-level taxonomy. For example, "Leonardo DiCaprio won an Oscar" returns "/art and entertainment/movies and tv/movies" as the most confident classification.
#
# #### Sentiment
# Determine whether your content conveys postive or negative sentiment. Sentiment information can be returned for detected entities, keywords, or user-specified target phrases found in the text.
#
# #### Emotion
# Detect anger, disgust, fear, joy, or sadness that is conveyed by your content. Emotion information can be returned for detected entities, keywords, or user-specified target phrases found in the text.
#
# #### Relations
# Recognize when two entities are related, and identify the type of relation. For example, you can identify an "awardedTo" relation between an award and its recipient.
#
# #### Semantic Roles
# Parse sentences into subject-action-object form, and identify entities and keywords that are subjects or objects of an action.

# %% [markdown]
# ## Analyzing text

# %%
text='After overtaking BMW last year as the world’s largest luxury automaker, \
Mercedes-Benz is turning its attention to a newer, untapped audience: \
millennials seeking smaller cars as they progress through the stages of early adulthood.'

# %%
response = natural_language_understanding.analyze(
            language = "en", text = text,
            features = Features(
                        entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            )).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 230,
#     "features": 1
#   },
#   "language": "en",
#   "entities": [
#     {
#       "type": "Company",
#       "text": "BMW",
#       "sentiment": {
#         "score": 0.216764,
#         "label": "positive"
#       },
#       "relevance": 0.33,
#       "emotion": {
#         "sadness": 0.212793,
#         "joy": 0.507769,
#         "fear": 0.064729,
#         "disgust": 0.03569,
#         "anger": 0.030211
#       },
#       "disambiguation": {
#         "subtype": [
#           "Engine",
#           "AutomobileCompany",
#           "AwardWinner"
#         ],
#         "name": "BMW",
#         "dbpedia_resource": "http://dbpedia.org/resource/BMW"
#       },
#       "count": 1
#     },
#     {
#       "type": "Company",
#       "text": "Mercedes-Benz",
#       "sentiment": {
#         "score": 0.736997,
#         "label": "positive"
#       },
#       "relevance": 0.33,
#       "emotion": {
#         "sadness": 0.375508,
#         "joy": 0.255631,
#         "fear": 0.137987,
#         "disgust": 0.036792,
#         "anger": 0.093049
#       },
#       "disambiguation": {
#         "subtype": [
#           "AutomotiveDesigner",
#           "AwardWinner"
#         ],
#         "name": "Mercedes-Benz",
#         "dbpedia_resource": "http://dbpedia.org/resource/Mercedes-Benz"
#       },
#       "count": 1
#     }
#   ]
# }

# %%
response = natural_language_understanding.analyze(
            text = text,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            )).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 230,
#     "features": 1
#   },
#   "language": "en",
#   "keywords": [
#     {
#       "text": "largest luxury automaker",
#       "sentiment": {
#         "score": 0.216764,
#         "label": "positive"
#       },
#       "relevance": 0.951351,
#       "emotion": {
#         "sadness": 0.212793,
#         "joy": 0.507769,
#         "fear": 0.064729,
#         "disgust": 0.03569,
#         "anger": 0.030211
#       }
#     },
#     {
#       "text": "untapped audience",
#       "sentiment": {
#         "score": 0.769293,
#         "label": "positive"
#       },
#       "relevance": 0.758759,
#       "emotion": {
#         "sadness": 0.151545,
#         "joy": 0.174219,
#         "fear": 0.093654,
#         "disgust": 0.072945,
#         "anger": 0.08686
#       }
#     },
#     {
#       "text": "early adulthood",
#       "sentiment": {
#         "score": 0.583717,
#         "label": "positive"
#       },
#       "relevance": 0.673927,
#       "emotion": {
#         "sadness": 0.073033,
#         "joy": 0.637075,
#         "fear": 0.078259,
#         "disgust": 0.123112,
#         "anger": 0.073193
#       }
#     },
#     {
#       "text": "smaller cars",
#       "sentiment": {
#         "score": 0.583717,
#         "label": "positive"
#       },
#       "relevance": 0.646383,
#       "emotion": {
#         "sadness": 0.073033,
#         "joy": 0.637075,
#         "fear": 0.078259,
#         "disgust": 0.123112,
#         "anger": 0.073193
#       }
#     },
#     {
#       "text": "Mercedes-Benz",
#       "sentiment": {
#         "score": 0.736997,
#         "label": "positive"
#       },
#       "relevance": 0.43985,
#       "emotion": {
#         "sadness": 0.375508,
#         "joy": 0.255631,
#         "fear": 0.137987,
#         "disgust": 0.036792,
#         "anger": 0.093049
#       }
#     },
#     {
#       "text": "BMW",
#       "sentiment": {
#         "score": 0.216764,
#         "label": "positive"
#       },
#       "relevance": 0.411539,
#       "emotion": {
#         "sadness": 0.212793,
#         "joy": 0.507769,
#         "fear": 0.064729,
#         "disgust": 0.03569,
#         "anger": 0.030211
#       }
#     },
#     {
#       "text": "attention",
#       "sentiment": {
#         "score": 0.736997,
#         "label": "positive"
#       },
#       "relevance": 0.4046,
#       "emotion": {
#         "sadness": 0.375508,
#         "joy": 0.255631,
#         "fear": 0.137987,
#         "disgust": 0.036792,
#         "anger": 0.093049
#       }
#     },
#     {
#       "text": "stages",
#       "sentiment": {
#         "score": 0.583717,
#         "label": "positive"
#       },
#       "relevance": 0.393549,
#       "emotion": {
#         "sadness": 0.073033,
#         "joy": 0.637075,
#         "fear": 0.078259,
#         "disgust": 0.123112,
#         "anger": 0.073193
#       }
#     },
#     {
#       "text": "world",
#       "sentiment": {
#         "score": 0.216764,
#         "label": "positive"
#       },
#       "relevance": 0.350317
#     }
#   ]
# }

# %%
response = natural_language_understanding.analyze(
            text = text,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            )).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 230,
#     "features": 1
#   },
#   "language": "en",
#   "concepts": [
#     {
#       "text": "BMW",
#       "relevance": 0.888452,
#       "dbpedia_resource": "http://dbpedia.org/resource/BMW"
#     },
#     {
#       "text": "Mercedes-Benz",
#       "relevance": 0.888266,
#       "dbpedia_resource": "http://dbpedia.org/resource/Mercedes-Benz"
#     },
#     {
#       "text": "Automotive industry",
#       "relevance": 0.882851,
#       "dbpedia_resource": "http://dbpedia.org/resource/Automotive_industry"
#     },
#     {
#       "text": "Luxury vehicle",
#       "relevance": 0.852593,
#       "dbpedia_resource": "http://dbpedia.org/resource/Luxury_vehicle"
#     },
#     {
#       "text": "Karl Benz",
#       "relevance": 0.780259,
#       "dbpedia_resource": "http://dbpedia.org/resource/Karl_Benz"
#     },
#     {
#       "text": "Diesel engine",
#       "relevance": 0.765713,
#       "dbpedia_resource": "http://dbpedia.org/resource/Diesel_engine"
#     },
#     {
#       "text": "World",
#       "relevance": 0.7476,
#       "dbpedia_resource": "http://dbpedia.org/resource/World"
#     },
#     {
#       "text": "Adult",
#       "relevance": 0.72744,
#       "dbpedia_resource": "http://dbpedia.org/resource/Adult"
#     },
#     {
#       "text": "Adulthood",
#       "relevance": 0.714,
#       "dbpedia_resource": "http://dbpedia.org/resource/Adulthood"
#     },
#     {
#       "text": "Earth",
#       "relevance": 0.6804,
#       "dbpedia_resource": "http://dbpedia.org/resource/Earth"
#     }
#   ]
# }

# %%
response = natural_language_understanding.analyze(
            text = text,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        categories = CategoriesOptions()
            )).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 230,
#     "features": 2
#   },
#   "relations": [
#     {
#       "type": "basedIn",
#       "sentence": "After overtaking BMW last year as the world's largest luxury automaker, Mercedes-Benz is turning its attention to a newer, untapped audience: millennials seeking smaller cars as they progress through the stages of early adulthood.",
#       "score": 0.808415,
#       "arguments": [
#         {
#           "text": "automaker",
#           "location": [
#             61,
#             70
#           ],
#           "entities": [
#             {
#               "type": "Organization",
#               "text": "Mercedes-Benz",
#               "disambiguation": {
#                 "subtype": [
#                   "Commercial"
#                 ]
#               }
#             }
#           ]
#         },
#         {
#           "text": "world",
#           "location": [
#             38,
#             43
#           ],
#           "entities": [
#             {
#               "type": "GeopoliticalEntity",
#               "text": "world",
#               "disambiguation": {
#                 "subtype": [
#                   "Area"
#                 ]
#               }
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "employedBy",
#       "sentence": "After overtaking BMW last year as the world's largest luxury automaker, Mercedes-Benz is turning its attention to a newer, untapped audience: millennials seeking smaller cars as they progress through the stages of early adulthood.",
#       "score": 0.31143,
#       "arguments": [
#         {
#           "text": "audience",
#           "location": [
#             132,
#             140
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "audience"
#             }
#           ]
#         },
#         {
#           "text": "its",
#           "location": [
#             97,
#             100
#           ],
#           "entities": [
#             {
#               "type": "Organization",
#               "text": "Mercedes-Benz",
#               "disambiguation": {
#                 "subtype": [
#                   "Commercial"
#                 ]
#               }
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "employedBy",
#       "sentence": "After overtaking BMW last year as the world's largest luxury automaker, Mercedes-Benz is turning its attention to a newer, untapped audience: millennials seeking smaller cars as they progress through the stages of early adulthood.",
#       "score": 0.277355,
#       "arguments": [
#         {
#           "text": "millennials",
#           "location": [
#             142,
#             153
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "millennials"
#             }
#           ]
#         },
#         {
#           "text": "its",
#           "location": [
#             97,
#             100
#           ],
#           "entities": [
#             {
#               "type": "Organization",
#               "text": "Mercedes-Benz",
#               "disambiguation": {
#                 "subtype": [
#                   "Commercial"
#                 ]
#               }
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "type": "locatedAt",
#       "sentence": "After overtaking BMW last year as the world's largest luxury automaker, Mercedes-Benz is turning its attention to a newer, untapped audience: millennials seeking smaller cars as they progress through the stages of early adulthood.",
#       "score": 0.636426,
#       "arguments": [
#         {
#           "text": "millennials",
#           "location": [
#             142,
#             153
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "text": "millennials"
#             }
#           ]
#         },
#         {
#           "text": "cars",
#           "location": [
#             170,
#             174
#           ],
#           "entities": [
#             {
#               "type": "Vehicle",
#               "text": "cars"
#             }
#           ]
#         }
#       ]
#     }
#   ],
#   "language": "en",
#   "categories": [
#     {
#       "score": 0.554889,
#       "label": "/automotive and vehicles/cars"
#     },
#     {
#       "score": 0.152065,
#       "label": "/automotive and vehicles/vehicle brands/mercedes-benz"
#     },
#     {
#       "score": 0.130826,
#       "label": "/business and industrial"
#     }
#   ]
# }

# %%
response = natural_language_understanding.analyze(
            text = text,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            )).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 230,
#     "features": 1
#   },
#   "sentiment": {
#     "document": {
#       "score": 0.906302,
#       "label": "positive"
#     }
#   },
#   "language": "en"
# }

# %%
response = natural_language_understanding.analyze(
            text = text,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            )).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 230,
#     "features": 1
#   },
#   "semantic_roles": [
#     {
#       "subject": {
#         "text": "the world",
#         "keywords": [
#           {
#             "text": "world"
#           }
#         ]
#       },
#       "sentence": "After overtaking BMW last year as the world\u2019s largest luxury automaker, Mercedes-Benz is turning its attention to a newer, untapped audience: millennials seeking smaller cars as they progress through the stages of early adulthood.",
#       "object": {
#         "text": "largest luxury automaker",
#         "keywords": [
#           {
#             "text": "largest luxury automaker"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "has",
#           "tense": "present"
#         },
#         "text": "s",
#         "normalized": "s"
#       }
#     },
#     {
#       "subject": {
#         "text": "Mercedes-Benz",
#         "keywords": [
#           {
#             "text": "Mercedes-Benz"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Company",
#             "text": "Mercedes-Benz",
#             "disambiguation": {
#               "subtype": [
#                 "Organization",
#                 "AutomotiveDesigner",
#                 "AwardWinner"
#               ],
#               "name": "Mercedes-Benz",
#               "dbpedia_resource": "http://dbpedia.org/resource/Mercedes-Benz"
#             }
#           }
#         ]
#       },
#       "sentence": "After overtaking BMW last year as the world\u2019s largest luxury automaker, Mercedes-Benz is turning its attention to a newer, untapped audience: millennials seeking smaller cars as they progress through the stages of early adulthood.",
#       "object": {
#         "text": "turning its attention to a newer, untapped audience",
#         "keywords": [
#           {
#             "text": "untapped audience"
#           },
#           {
#             "text": "attention"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "present"
#         },
#         "text": "is",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "Mercedes-Benz",
#         "keywords": [
#           {
#             "text": "Mercedes-Benz"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Company",
#             "text": "Mercedes-Benz",
#             "disambiguation": {
#               "subtype": [
#                 "Organization",
#                 "AutomotiveDesigner",
#                 "AwardWinner"
#               ],
#               "name": "Mercedes-Benz",
#               "dbpedia_resource": "http://dbpedia.org/resource/Mercedes-Benz"
#             }
#           }
#         ]
#       },
#       "sentence": "After overtaking BMW last year as the world\u2019s largest luxury automaker, Mercedes-Benz is turning its attention to a newer, untapped audience: millennials seeking smaller cars as they progress through the stages of early adulthood.",
#       "object": {
#         "text": "its attention",
#         "keywords": [
#           {
#             "text": "attention"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "turn",
#           "tense": "present"
#         },
#         "text": "is turning",
#         "normalized": "be turn"
#       }
#     },
#     {
#       "subject": {
#         "text": "millennials",
#         "keywords": [
#           {
#             "text": "millennials"
#           }
#         ]
#       },
#       "sentence": "After overtaking BMW last year as the world\u2019s largest luxury automaker, Mercedes-Benz is turning its attention to a newer, untapped audience: millennials seeking smaller cars as they progress through the stages of early adulthood.",
#       "object": {
#         "text": "smaller cars",
#         "keywords": [
#           {
#             "text": "smaller cars"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "seek",
#           "tense": "present"
#         },
#         "text": "seeking",
#         "normalized": "seek"
#       }
#     }
#   ],
#   "language": "en"
# }

# %%
response = natural_language_understanding.analyze(
            text = text,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            )).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 230,
#     "features": 1
#   },
#   "language": "en",
#   "emotion": {
#     "document": {
#       "emotion": {
#         "sadness": 0.19455,
#         "joy": 0.595719,
#         "fear": 0.069535,
#         "disgust": 0.050423,
#         "anger": 0.046226
#       }
#     }
#   }
# }

# %%
response = natural_language_understanding.analyze(
            text = text,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        categories = CategoriesOptions()
            )).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 230,
#     "features": 1
#   },
#   "language": "en",
#   "categories": [
#     {
#       "score": 0.554889,
#       "label": "/automotive and vehicles/cars"
#     },
#     {
#       "score": 0.152065,
#       "label": "/automotive and vehicles/vehicle brands/mercedes-benz"
#     },
#     {
#       "score": 0.130826,
#       "label": "/business and industrial"
#     }
#   ]
# }

# %% [markdown]
# ## Analyzing URLS

# %%
url='http://www.chicagotribune.com/news/local/breaking/ct-fbi-chase-bank-branch-robbed-on-far-south-side-20170524-story.html'

response = natural_language_understanding.analyze(
            url = url,
            features = Features(
                        entities = EntitiesOptions(sentiment = True, emotion = True),
                        keywords = KeywordsOptions(sentiment = True, emotion = True),
                        concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            )).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 811,
#     "features": 3
#   },
#   "retrieved_url": "http://www.chicagotribune.com/news/local/breaking/ct-fbi-chase-bank-branch-robbed-on-far-south-side-20170524-story.html",
#   "language": "en",
#   "keywords": [
#     {
#       "text": "would-be robber",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.97343,
#       "emotion": {
#         "sadness": 0.23608,
#         "joy": 0.086439,
#         "fear": 0.177302,
#         "disgust": 0.416375,
#         "anger": 0.214233
#       }
#     },
#     {
#       "text": "Calumet Heights neighborhood",
#       "sentiment": {
#         "score": -0.567525,
#         "label": "negative"
#       },
#       "relevance": 0.879791,
#       "emotion": {
#         "sadness": 0.376757,
#         "joy": 0.307912,
#         "fear": 0.100655,
#         "disgust": 0.191158,
#         "anger": 0.098523
#       }
#     },
#     {
#       "text": "Chase Bank",
#       "sentiment": {
#         "score": -0.567525,
#         "label": "negative"
#       },
#       "relevance": 0.864905,
#       "emotion": {
#         "sadness": 0.396781,
#         "joy": 0.227727,
#         "fear": 0.10534,
#         "disgust": 0.139012,
#         "anger": 0.108463
#       }
#     },
#     {
#       "text": "Chase Bank branch",
#       "sentiment": {
#         "score": -0.567525,
#         "label": "negative"
#       },
#       "relevance": 0.847705,
#       "emotion": {
#         "sadness": 0.376757,
#         "joy": 0.307912,
#         "fear": 0.100655,
#         "disgust": 0.191158,
#         "anger": 0.098523
#       }
#     },
#     {
#       "text": "S. Jeffery Blvd.",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.772957
#     },
#     {
#       "text": "FBI spokesman",
#       "sentiment": {
#         "score": -0.404007,
#         "label": "negative"
#       },
#       "relevance": 0.761774,
#       "emotion": {
#         "sadness": 0.441087,
#         "joy": 0.019109,
#         "fear": 0.149402,
#         "disgust": 0.40223,
#         "anger": 0.277893
#       }
#     },
#     {
#       "text": "yellow work vest",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.723126,
#       "emotion": {
#         "sadness": 0.243479,
#         "joy": 0.301258,
#         "fear": 0.189485,
#         "disgust": 0.07674,
#         "anger": 0.180288
#       }
#     },
#     {
#       "text": "dark colored pants",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.705049,
#       "emotion": {
#         "sadness": 0.337738,
#         "joy": 0.05809,
#         "fear": 0.417989,
#         "disgust": 0.297746,
#         "anger": 0.106481
#       }
#     },
#     {
#       "text": "Wednesday morning",
#       "sentiment": {
#         "score": -0.567525,
#         "label": "negative"
#       },
#       "relevance": 0.461158,
#       "emotion": {
#         "sadness": 0.376757,
#         "joy": 0.307912,
#         "fear": 0.100655,
#         "disgust": 0.191158,
#         "anger": 0.098523
#       }
#     },
#     {
#       "text": "white hardhat",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.452673,
#       "emotion": {
#         "sadness": 0.130342,
#         "joy": 0.146316,
#         "fear": 0.076505,
#         "disgust": 0.378072,
#         "anger": 0.085607
#       }
#     },
#     {
#       "text": "Armour mask",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.421174,
#       "emotion": {
#         "sadness": 0.426719,
#         "joy": 0.115403,
#         "fear": 0.122952,
#         "disgust": 0.442834,
#         "anger": 0.089563
#       }
#     },
#     {
#       "text": "slim build",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.408131,
#       "emotion": {
#         "sadness": 0.090018,
#         "joy": 0.299305,
#         "fear": 0.055553,
#         "disgust": 0.060972,
#         "anger": 0.04714
#       }
#     },
#     {
#       "text": "Earlier information",
#       "sentiment": {
#         "score": -0.527533,
#         "label": "negative"
#       },
#       "relevance": 0.404156,
#       "emotion": {
#         "sadness": 0.059115,
#         "joy": 0.427062,
#         "fear": 0.029166,
#         "disgust": 0.009774,
#         "anger": 0.024569
#       }
#     },
#     {
#       "text": "surveillance photo",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.361838,
#       "emotion": {
#         "sadness": 0.193412,
#         "joy": 0.095615,
#         "fear": 0.188651,
#         "disgust": 0.31484,
#         "anger": 0.211257
#       }
#     },
#     {
#       "text": "Chicago office",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.359322,
#       "emotion": {
#         "sadness": 0.221163,
#         "joy": 0.093333,
#         "fear": 0.135639,
#         "disgust": 0.283389,
#         "anger": 0.203137
#       }
#     },
#     {
#       "text": "low resolution",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.35032,
#       "emotion": {
#         "sadness": 0.401284,
#         "joy": 0.026079,
#         "fear": 0.153046,
#         "disgust": 0.468145,
#         "anger": 0.08525
#       }
#     },
#     {
#       "text": "black man",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.349437,
#       "emotion": {
#         "sadness": 0.265193,
#         "joy": 0.099865,
#         "fear": 0.160373,
#         "disgust": 0.390831,
#         "anger": 0.157866
#       }
#     },
#     {
#       "text": "robbery",
#       "sentiment": {
#         "score": -0.46293,
#         "label": "negative"
#       },
#       "relevance": 0.276157,
#       "emotion": {
#         "sadness": 0.168016,
#         "joy": 0.108108,
#         "fear": 0.087392,
#         "disgust": 0.017073,
#         "anger": 0.030652
#       }
#     }
#   ],
#   "entities": [
#     {
#       "type": "Organization",
#       "text": "FBI",
#       "sentiment": {
#         "score": -0.404007,
#         "label": "negative"
#       },
#       "relevance": 0.902431,
#       "emotion": {
#         "sadness": 0.1792,
#         "joy": 0.088157,
#         "fear": 0.186275,
#         "disgust": 0.3797,
#         "anger": 0.310301
#       },
#       "disambiguation": {
#         "subtype": [
#           "GovernmentAgency",
#           "GovernmentalBody"
#         ],
#         "name": "Federal Bureau of Investigation",
#         "dbpedia_resource": "http://dbpedia.org/resource/Federal_Bureau_of_Investigation"
#       },
#       "count": 5
#     },
#     {
#       "type": "Crime",
#       "text": "attempted robbery",
#       "sentiment": {
#         "score": -0.46293,
#         "label": "negative"
#       },
#       "relevance": 0.488685,
#       "emotion": {
#         "sadness": 0.168016,
#         "joy": 0.108108,
#         "fear": 0.087392,
#         "disgust": 0.017073,
#         "anger": 0.030652
#       },
#       "count": 2
#     },
#     {
#       "type": "Company",
#       "text": "Chase Bank",
#       "sentiment": {
#         "score": -0.567525,
#         "label": "negative"
#       },
#       "relevance": 0.46852,
#       "emotion": {
#         "sadness": 0.396781,
#         "joy": 0.227727,
#         "fear": 0.10534,
#         "disgust": 0.139012,
#         "anger": 0.108463
#       },
#       "disambiguation": {
#         "subtype": [],
#         "name": "Chase (bank)",
#         "dbpedia_resource": "http://dbpedia.org/resource/Chase_(bank)"
#       },
#       "count": 2
#     },
#     {
#       "type": "Location",
#       "text": "Calumet Heights",
#       "sentiment": {
#         "score": -0.567525,
#         "label": "negative"
#       },
#       "relevance": 0.259034,
#       "emotion": {
#         "sadness": 0.376757,
#         "joy": 0.307912,
#         "fear": 0.100655,
#         "disgust": 0.191158,
#         "anger": 0.098523
#       },
#       "disambiguation": {
#         "subtype": [
#           "City"
#         ]
#       },
#       "count": 1
#     },
#     {
#       "type": "Person",
#       "text": "rob",
#       "sentiment": {
#         "score": -0.567525,
#         "label": "negative"
#       },
#       "relevance": 0.21717,
#       "emotion": {
#         "sadness": 0.376757,
#         "joy": 0.307912,
#         "fear": 0.100655,
#         "disgust": 0.191158,
#         "anger": 0.098523
#       },
#       "count": 1
#     },
#     {
#       "type": "Location",
#       "text": "Chicago",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.189571,
#       "emotion": {
#         "sadness": 0.221163,
#         "joy": 0.093333,
#         "fear": 0.135639,
#         "disgust": 0.283389,
#         "anger": 0.203137
#       },
#       "disambiguation": {
#         "subtype": [
#           "City"
#         ],
#         "name": "Chicago",
#         "dbpedia_resource": "http://dbpedia.org/resource/Chicago"
#       },
#       "count": 1
#     },
#     {
#       "type": "Quantity",
#       "text": "5-foot",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.189571,
#       "count": 2
#     }
#   ],
#   "concepts": [
#     {
#       "text": "Bank robbery",
#       "relevance": 0.951185,
#       "dbpedia_resource": "http://dbpedia.org/resource/Bank_robbery"
#     },
#     {
#       "text": "White people",
#       "relevance": 0.852973,
#       "dbpedia_resource": "http://dbpedia.org/resource/White_people"
#     },
#     {
#       "text": "Color",
#       "relevance": 0.749349,
#       "dbpedia_resource": "http://dbpedia.org/resource/Color"
#     },
#     {
#       "text": "Robbery",
#       "relevance": 0.744865,
#       "dbpedia_resource": "http://dbpedia.org/resource/Robbery"
#     },
#     {
#       "text": "United Kingdom",
#       "relevance": 0.723957,
#       "dbpedia_resource": "http://dbpedia.org/resource/United_Kingdom"
#     },
#     {
#       "text": "Crime",
#       "relevance": 0.691178,
#       "dbpedia_resource": "http://dbpedia.org/resource/Crime"
#     },
#     {
#       "text": "African American",
#       "relevance": 0.687616,
#       "dbpedia_resource": "http://dbpedia.org/resource/African_American"
#     },
#     {
#       "text": "Theft",
#       "relevance": 0.677833,
#       "dbpedia_resource": "http://dbpedia.org/resource/Theft"
#     },
#     {
#       "text": "Chicago",
#       "relevance": 0.618643,
#       "dbpedia_resource": "http://dbpedia.org/resource/Chicago"
#     }
#   ]
# }

# %%
response = natural_language_understanding.analyze(
            url = url,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            )).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 811,
#     "features": 1
#   },
#   "semantic_roles": [
#     {
#       "subject": {
#         "text": "A man",
#         "keywords": [
#           {
#             "text": "man"
#           }
#         ]
#       },
#       "sentence": "A man tried to rob a Chase Bank branch Wednesday morning in the Calumet Heights neighborhood on the Far South Side, the FBI said.",
#       "object": {
#         "text": "to rob a Chase Bank branch",
#         "keywords": [
#           {
#             "text": "Chase Bank branch"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Person",
#             "text": "rob"
#           },
#           {
#             "type": "Company",
#             "text": "Chase Bank",
#             "disambiguation": {
#               "subtype": [
#                 "Company"
#               ],
#               "name": "Chase (bank)",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chase_(bank)"
#             }
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "try",
#           "tense": "past"
#         },
#         "text": "tried",
#         "normalized": "try"
#       }
#     },
#     {
#       "subject": {
#         "text": "A man",
#         "keywords": [
#           {
#             "text": "man"
#           }
#         ]
#       },
#       "sentence": "A man tried to rob a Chase Bank branch Wednesday morning in the Calumet Heights neighborhood on the Far South Side, the FBI said.",
#       "object": {
#         "text": "a Chase Bank branch",
#         "keywords": [
#           {
#             "text": "Chase Bank branch"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Company",
#             "text": "Chase Bank",
#             "disambiguation": {
#               "subtype": [
#                 "Company"
#               ],
#               "name": "Chase (bank)",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chase_(bank)"
#             }
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "rob",
#           "tense": "future"
#         },
#         "text": "tried to rob",
#         "normalized": "try to rob"
#       }
#     },
#     {
#       "subject": {
#         "text": "the FBI",
#         "keywords": [
#           {
#             "text": "FBI"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "FBI",
#             "disambiguation": {
#               "subtype": [
#                 "GovernmentAgency",
#                 "GovernmentalBody"
#               ],
#               "name": "Federal Bureau of Investigation",
#               "dbpedia_resource": "http://dbpedia.org/resource/Federal_Bureau_of_Investigation"
#             }
#           }
#         ]
#       },
#       "sentence": "A man tried to rob a Chase Bank branch Wednesday morning in the Calumet Heights neighborhood on the Far South Side, the FBI said.",
#       "object": {
#         "text": "A man tried to rob a Chase Bank branch Wednesday morning in the Calumet Heights neighborhood on the Far South Side",
#         "keywords": [
#           {
#             "text": "Calumet Heights neighborhood"
#           },
#           {
#             "text": "Chase Bank branch"
#           },
#           {
#             "text": "Wednesday morning"
#           },
#           {
#             "text": "man"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Person",
#             "text": "rob"
#           },
#           {
#             "type": "Company",
#             "text": "Chase Bank",
#             "disambiguation": {
#               "subtype": [
#                 "Company"
#               ],
#               "name": "Chase (bank)",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chase_(bank)"
#             }
#           },
#           {
#             "type": "Location",
#             "text": "Calumet Heights",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             }
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "say",
#           "tense": "past"
#         },
#         "text": "said",
#         "normalized": "say"
#       }
#     },
#     {
#       "subject": {
#         "text": "The attempted robbery",
#         "keywords": [
#           {
#             "text": "robbery"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Crime",
#             "text": "attempted robbery"
#           }
#         ]
#       },
#       "sentence": " The attempted robbery happened shortly after 8:20 a.m. at a Chase Bank at 9450 S. Jeffery Blvd., officials said.",
#       "action": {
#         "verb": {
#           "text": "happen",
#           "tense": "past"
#         },
#         "text": "happened",
#         "normalized": "happen"
#       }
#     },
#     {
#       "subject": {
#         "text": "officials",
#         "keywords": [
#           {
#             "text": "officials"
#           }
#         ]
#       },
#       "sentence": " The attempted robbery happened shortly after 8:20 a.m. at a Chase Bank at 9450 S. Jeffery Blvd., officials said.",
#       "action": {
#         "verb": {
#           "text": "say",
#           "tense": "past"
#         },
#         "text": "said",
#         "normalized": "say"
#       }
#     },
#     {
#       "subject": {
#         "text": "the robbery",
#         "keywords": [
#           {
#             "text": "robbery"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Crime",
#             "text": "attempted robbery"
#           }
#         ]
#       },
#       "sentence": " Earlier information had been that the robbery was successful, but that was not correct, an FBI spokesman said.",
#       "object": {
#         "text": "successful"
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "past"
#         },
#         "text": "was",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "an FBI spokesman",
#         "keywords": [
#           {
#             "text": "FBI spokesman"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "FBI",
#             "disambiguation": {
#               "subtype": [
#                 "GovernmentAgency",
#                 "GovernmentalBody"
#               ],
#               "name": "Federal Bureau of Investigation",
#               "dbpedia_resource": "http://dbpedia.org/resource/Federal_Bureau_of_Investigation"
#             }
#           }
#         ]
#       },
#       "sentence": " Earlier information had been that the robbery was successful, but that was not correct, an FBI spokesman said.",
#       "object": {
#         "text": "Earlier information had been that the robbery was successful, but that was not correct",
#         "keywords": [
#           {
#             "text": "Earlier information"
#           },
#           {
#             "text": "robbery"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Crime",
#             "text": "attempted robbery"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "say",
#           "tense": "past"
#         },
#         "text": "said",
#         "normalized": "say"
#       }
#     },
#     {
#       "subject": {
#         "text": "The would-be robber",
#         "keywords": [
#           {
#             "text": "would-be robber"
#           }
#         ]
#       },
#       "sentence": " The would-be robber was described as a black man, standing about 5-foot-5 to 5-foot-7, with a slim build.",
#       "object": {
#         "text": "described as a black man",
#         "keywords": [
#           {
#             "text": "black man"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "past"
#         },
#         "text": "was",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "The would-be robber",
#         "keywords": [
#           {
#             "text": "would-be robber"
#           }
#         ]
#       },
#       "sentence": " The would-be robber was described as a black man, standing about 5-foot-5 to 5-foot-7, with a slim build.",
#       "object": {
#         "text": "as a black man, standing about 5-foot-5 to 5-foot-7, with a slim build",
#         "keywords": [
#           {
#             "text": "slim build"
#           },
#           {
#             "text": "black man"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Quantity",
#             "text": "5-foot"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "describe",
#           "tense": "past"
#         },
#         "text": "was described",
#         "normalized": "be describe"
#       }
#     },
#     {
#       "subject": {
#         "text": "a black man",
#         "keywords": [
#           {
#             "text": "black man"
#           }
#         ]
#       },
#       "sentence": " The would-be robber was described as a black man, standing about 5-foot-5 to 5-foot-7, with a slim build.",
#       "object": {
#         "text": "about 5-foot-5",
#         "entities": [
#           {
#             "type": "Quantity",
#             "text": "5-foot"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "stand",
#           "tense": "present"
#         },
#         "text": "standing",
#         "normalized": "stand"
#       }
#     },
#     {
#       "subject": {
#         "text": "He"
#       },
#       "sentence": " He was wearing a white hardhat, an orange and yellow work vest, and dark colored pants, with a black Under Armour mask covering his face, according to the FBI.",
#       "object": {
#         "text": "wearing a white hardhat, an orange and yellow work vest, and dark colored pants, with a black Under Armour mask covering his face",
#         "keywords": [
#           {
#             "text": "yellow work vest"
#           },
#           {
#             "text": "dark colored pants"
#           },
#           {
#             "text": "white hardhat"
#           },
#           {
#             "text": "Armour mask"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "past"
#         },
#         "text": "was",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "He"
#       },
#       "sentence": " He was wearing a white hardhat, an orange and yellow work vest, and dark colored pants, with a black Under Armour mask covering his face, according to the FBI.",
#       "object": {
#         "text": "a white hardhat, an orange and yellow work vest, and dark colored pants",
#         "keywords": [
#           {
#             "text": "yellow work vest"
#           },
#           {
#             "text": "dark colored pants"
#           },
#           {
#             "text": "white hardhat"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "wear",
#           "tense": "past"
#         },
#         "text": "was wearing",
#         "normalized": "be wear"
#       }
#     },
#     {
#       "subject": {
#         "text": "his face",
#         "keywords": [
#           {
#             "text": "face"
#           }
#         ]
#       },
#       "sentence": " He was wearing a white hardhat, an orange and yellow work vest, and dark colored pants, with a black Under Armour mask covering his face, according to the FBI.",
#       "object": {
#         "text": "a black Under Armour mask",
#         "keywords": [
#           {
#             "text": "Armour mask"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "cover",
#           "tense": "present"
#         },
#         "text": "covering",
#         "normalized": "cover"
#       }
#     },
#     {
#       "subject": {
#         "text": "an orange and yellow work vest, and dark colored pants",
#         "keywords": [
#           {
#             "text": "yellow work vest"
#           },
#           {
#             "text": "dark colored pants"
#           },
#           {
#             "text": "orange"
#           }
#         ]
#       },
#       "sentence": " He was wearing a white hardhat, an orange and yellow work vest, and dark colored pants, with a black Under Armour mask covering his face, according to the FBI.",
#       "object": {
#         "text": "to the FBI",
#         "keywords": [
#           {
#             "text": "FBI"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "FBI",
#             "disambiguation": {
#               "subtype": [
#                 "GovernmentAgency",
#                 "GovernmentalBody"
#               ],
#               "name": "Federal Bureau of Investigation",
#               "dbpedia_resource": "http://dbpedia.org/resource/Federal_Bureau_of_Investigation"
#             }
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "accord",
#           "tense": "present"
#         },
#         "text": "according",
#         "normalized": "accord"
#       }
#     },
#     {
#       "subject": {
#         "text": "The FBI",
#         "keywords": [
#           {
#             "text": "FBI"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "FBI",
#             "disambiguation": {
#               "subtype": [
#                 "GovernmentAgency",
#                 "GovernmentalBody"
#               ],
#               "name": "Federal Bureau of Investigation",
#               "dbpedia_resource": "http://dbpedia.org/resource/Federal_Bureau_of_Investigation"
#             }
#           }
#         ]
#       },
#       "sentence": " The FBI released a surveillance photo of the would-be robber, but it was low resolution.",
#       "object": {
#         "text": "a surveillance photo of the would-be robber",
#         "keywords": [
#           {
#             "text": "would-be robber"
#           },
#           {
#             "text": "surveillance photo"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "release",
#           "tense": "past"
#         },
#         "text": "released",
#         "normalized": "release"
#       }
#     },
#     {
#       "subject": {
#         "text": "Anyone with information about the man",
#         "keywords": [
#           {
#             "text": "information"
#           },
#           {
#             "text": "man"
#           }
#         ]
#       },
#       "sentence": " Anyone with information about the man is asked to call the Chicago office of the FBI at 312-421-6700.",
#       "object": {
#         "text": "the Chicago office of the FBI",
#         "keywords": [
#           {
#             "text": "FBI"
#           },
#           {
#             "text": "Chicago office"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Location",
#             "text": "Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ],
#               "name": "Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chicago"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "FBI",
#             "disambiguation": {
#               "subtype": [
#                 "GovernmentAgency",
#                 "GovernmentalBody"
#               ],
#               "name": "Federal Bureau of Investigation",
#               "dbpedia_resource": "http://dbpedia.org/resource/Federal_Bureau_of_Investigation"
#             }
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "call",
#           "tense": "future"
#         },
#         "text": "is asked to call",
#         "normalized": "be ask to call"
#       }
#     }
#   ],
#   "retrieved_url": "http://www.chicagotribune.com/news/local/breaking/ct-fbi-chase-bank-branch-robbed-on-far-south-side-20170524-story.html",
#   "language": "en"
# }

# %% [markdown]
# ### Semantically difficult examples

# %%
url='http://www.cnbc.com/2017/05/11/caterpillar-earnings-will-beat-all-year-long-bank-of-america-says.html'

response = natural_language_understanding.analyze(
            url = url,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            )).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 1037,
#     "features": 1
#   },
#   "retrieved_url": "https://www.cnbc.com/2017/05/11/caterpillar-earnings-will-beat-all-year-long-bank-of-america-says.html",
#   "language": "en",
#   "concepts": [
#     {
#       "text": "Bank of America",
#       "relevance": 0.955122,
#       "dbpedia_resource": "http://dbpedia.org/resource/Bank_of_America"
#     },
#     {
#       "text": "Merrill Lynch",
#       "relevance": 0.88865,
#       "dbpedia_resource": "http://dbpedia.org/resource/Merrill_Lynch"
#     },
#     {
#       "text": "Private banking",
#       "relevance": 0.571594,
#       "dbpedia_resource": "http://dbpedia.org/resource/Private_banking"
#     },
#     {
#       "text": "Stock",
#       "relevance": 0.551895,
#       "dbpedia_resource": "http://dbpedia.org/resource/Stock"
#     },
#     {
#       "text": "Troubled Asset Relief Program",
#       "relevance": 0.485637,
#       "dbpedia_resource": "http://dbpedia.org/resource/Troubled_Asset_Relief_Program"
#     },
#     {
#       "text": "Morgan Stanley",
#       "relevance": 0.46867,
#       "dbpedia_resource": "http://dbpedia.org/resource/Morgan_Stanley"
#     },
#     {
#       "text": "Stock market",
#       "relevance": 0.442562,
#       "dbpedia_resource": "http://dbpedia.org/resource/Stock_market"
#     },
#     {
#       "text": "Subprime mortgage crisis",
#       "relevance": 0.439713,
#       "dbpedia_resource": "http://dbpedia.org/resource/Subprime_mortgage_crisis"
#     },
#     {
#       "text": "Safeway Inc.",
#       "relevance": 0.428831,
#       "dbpedia_resource": "http://dbpedia.org/resource/Safeway_Inc."
#     }
#   ]
# }

# %%
text="Caterpillar earnings will 'beat all year long,' Bank of America says"

response = natural_language_understanding.analyze(
            text = text,
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        #sentiment = SentimentOptions(),
                        semantic_roles = SemanticRolesOptions(entities = True, keywords = True)
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            )).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 68,
#     "features": 1
#   },
#   "semantic_roles": [
#     {
#       "subject": {
#         "text": "Caterpillar earnings",
#         "keywords": [
#           {
#             "text": "Caterpillar earnings"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Company",
#             "text": "Caterpillar"
#           }
#         ]
#       },
#       "sentence": "Caterpillar earnings will 'beat all year long,' Bank of America says",
#       "action": {
#         "verb": {
#           "text": "'beat",
#           "tense": "future"
#         },
#         "text": "will 'beat",
#         "normalized": "will 'beat"
#       }
#     },
#     {
#       "subject": {
#         "text": "Bank of America",
#         "keywords": [
#           {
#             "text": "Bank"
#           },
#           {
#             "text": "America"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Company",
#             "text": "Bank of America"
#           }
#         ]
#       },
#       "sentence": "Caterpillar earnings will 'beat all year long,' Bank of America says",
#       "object": {
#         "text": "Caterpillar earnings will 'beat all year long",
#         "keywords": [
#           {
#             "text": "Caterpillar earnings"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Company",
#             "text": "Caterpillar"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "say",
#           "tense": "present"
#         },
#         "text": "says",
#         "normalized": "say"
#       }
#     }
#   ],
#   "language": "en"
# }

# %% [markdown]
# ## Expect the explosion of data volumes

# %%
url='https://en.wikipedia.org/wiki/University_of_Chicago'

response = natural_language_understanding.analyze(
            url = url,
            features = Features(
                        entities = EntitiesOptions(sentiment = True, emotion = True),
                        keywords = KeywordsOptions(sentiment = True, emotion = True),
                        concepts = ConceptsOptions(limit = 50),
                        relations = RelationsOptions(),
                        sentiment = SentimentOptions(),
                        semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        emotion = EmotionOptions(),
                        categories = CategoriesOptions()
            )).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 5,
#     "text_characters": 50000,
#     "features": 8
#   },
#   "sentiment": {
#     "document": {
#       "score": -0.0595008,
#       "label": "negative"
#     }
#   },
#   "semantic_roles": [
#     {
#       "subject": {
#         "text": "University of Illinois at Chicago",
#         "keywords": [
#           {
#             "text": "Illinois"
#           },
#           {
#             "text": "Chicago"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "University of Illinois",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "AcademicInstitution",
#                 "CollegeUniversity"
#               ],
#               "name": "University of Illinois at Urbana\u2013Champaign",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Illinois_at_Urbana\u2013Champaign"
#             }
#           },
#           {
#             "type": "Location",
#             "text": "Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ],
#               "name": "Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chicago"
#             }
#           }
#         ]
#       },
#       "sentence": "For the public university in the University of Illinois System, see University of Illinois at Chicago.",
#       "action": {
#         "verb": {
#           "text": "see",
#           "tense": "present"
#         },
#         "text": "see",
#         "normalized": "see"
#       }
#     },
#     {
#       "subject": {
#         "text": "The University of Chicago (UChicago, U of C, or Chicago)",
#         "keywords": [
#           {
#             "text": "Chicago"
#           },
#           {
#             "text": "University"
#           },
#           {
#             "text": "UChicago"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "University of Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "Company",
#                 "PeriodicalPublisher",
#                 "CollegeUniversity"
#               ],
#               "name": "University of Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago"
#             }
#           },
#           {
#             "type": "Location",
#             "text": "Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ],
#               "name": "Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chicago"
#             }
#           }
#         ]
#       },
#       "sentence": " The University of Chicago (UChicago, U of C, or Chicago) is a private, non-profit research university in Chicago, Illinois.",
#       "object": {
#         "text": "a private, non-profit research university in Chicago, Illinois",
#         "keywords": [
#           {
#             "text": "non-profit research university"
#           },
#           {
#             "text": "Chicago"
#           },
#           {
#             "text": "Illinois"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Location",
#             "text": "Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ],
#               "name": "Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chicago"
#             }
#           },
#           {
#             "type": "Location",
#             "text": "Illinois",
#             "disambiguation": {
#               "subtype": [
#                 "PoliticalDistrict",
#                 "AdministrativeDivision",
#                 "GovernmentalJurisdiction",
#                 "USState",
#                 "StateOrCounty"
#               ],
#               "name": "Illinois",
#               "dbpedia_resource": "http://dbpedia.org/resource/Illinois"
#             }
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "present"
#         },
#         "text": "is",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "The university",
#         "keywords": [
#           {
#             "text": "university"
#           }
#         ],
#         "entities": []
#       },
#       "sentence": " The university is composed of an undergraduate college, various graduate programs and interdisciplinary committees organized into five academic research divisions and seven professional schools.",
#       "object": {
#         "text": "composed of an undergraduate college, various graduate programs and interdisciplinary committees organized into five academic research divisions and seven professional schools",
#         "keywords": [
#           {
#             "text": "academic research divisions"
#           },
#           {
#             "text": "various graduate programs"
#           },
#           {
#             "text": "interdisciplinary committees"
#           },
#           {
#             "text": "undergraduate college"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "present"
#         },
#         "text": "is",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "The university",
#         "keywords": [
#           {
#             "text": "university"
#           }
#         ],
#         "entities": []
#       },
#       "sentence": " The university is composed of an undergraduate college, various graduate programs and interdisciplinary committees organized into five academic research divisions and seven professional schools.",
#       "object": {
#         "text": "of an undergraduate college, various graduate programs and interdisciplinary committees organized into five academic research divisions and seven professional schools",
#         "keywords": [
#           {
#             "text": "academic research divisions"
#           },
#           {
#             "text": "various graduate programs"
#           },
#           {
#             "text": "interdisciplinary committees"
#           },
#           {
#             "text": "undergraduate college"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "compose",
#           "tense": "past"
#         },
#         "text": "is composed",
#         "normalized": "be compose"
#       }
#     },
#     {
#       "subject": {
#         "text": "Beyond the arts and sciences, Chicago",
#         "keywords": [
#           {
#             "text": "arts"
#           },
#           {
#             "text": "sciences"
#           },
#           {
#             "text": "Chicago"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Location",
#             "text": "Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ],
#               "name": "Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chicago"
#             }
#           }
#         ]
#       },
#       "sentence": " Beyond the arts and sciences, Chicago is also well known for its professional schools, which include the Pritzker School of Medicine, the Booth School of Business, the Law School, the School of Social Service Administration, the Harris School of Public Policy Studies, the Divinity School and the Graham School of Continuing Liberal and Professional Studies.",
#       "object": {
#         "text": "well known for its professional schools, which include the Pritzker School of Medicine, the Booth School of Business, the Law School, the School of Social Service Administration, the Harris School of Public Policy Studies, the Divinity School and the Graham School of Continuing Liberal and Professional Studies",
#         "keywords": [
#           {
#             "text": "Social Service Administration"
#           },
#           {
#             "text": "Public Policy Studies"
#           },
#           {
#             "text": "Pritzker School"
#           },
#           {
#             "text": "Continuing Liberal"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "Pritzker School of Medicine",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "CollegeUniversity",
#                 "University"
#               ],
#               "name": "Pritzker School of Medicine",
#               "dbpedia_resource": "http://dbpedia.org/resource/Pritzker_School_of_Medicine"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Booth School of Business",
#             "disambiguation": {
#               "subtype": [],
#               "name": "Booth School of Business",
#               "dbpedia_resource": "http://dbpedia.org/resource/Booth_School_of_Business"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "School of Social Service Administration",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "CollegeUniversity",
#                 "University"
#               ],
#               "name": "University of Chicago School of Social Service Administration",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_School_of_Social_Service_Administration"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Harris School of Public Policy Studies",
#             "disambiguation": {
#               "subtype": [
#                 "University"
#               ],
#               "name": "Harris School of Public Policy Studies",
#               "dbpedia_resource": "http://dbpedia.org/resource/Harris_School_of_Public_Policy_Studies"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Divinity School",
#             "disambiguation": {
#               "subtype": [
#                 "CollegeUniversity",
#                 "Company",
#                 "University"
#               ],
#               "name": "University of Chicago Divinity School",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_Divinity_School"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Graham School of Continuing Liberal"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "present"
#         },
#         "text": "is",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "Beyond the arts and sciences, Chicago",
#         "keywords": [
#           {
#             "text": "arts"
#           },
#           {
#             "text": "sciences"
#           },
#           {
#             "text": "Chicago"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Location",
#             "text": "Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ],
#               "name": "Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/Chicago"
#             }
#           }
#         ]
#       },
#       "sentence": " Beyond the arts and sciences, Chicago is also well known for its professional schools, which include the Pritzker School of Medicine, the Booth School of Business, the Law School, the School of Social Service Administration, the Harris School of Public Policy Studies, the Divinity School and the Graham School of Continuing Liberal and Professional Studies.",
#       "object": {
#         "text": "for its professional schools, which include the Pritzker School of Medicine, the Booth School of Business, the Law School, the School of Social Service Administration, the Harris School of Public Policy Studies, the Divinity School and the Graham School of Continuing Liberal and Professional Studies",
#         "keywords": [
#           {
#             "text": "Social Service Administration"
#           },
#           {
#             "text": "Public Policy Studies"
#           },
#           {
#             "text": "Pritzker School"
#           },
#           {
#             "text": "Continuing Liberal"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "Pritzker School of Medicine",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "CollegeUniversity",
#                 "University"
#               ],
#               "name": "Pritzker School of Medicine",
#               "dbpedia_resource": "http://dbpedia.org/resource/Pritzker_School_of_Medicine"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Booth School of Business",
#             "disambiguation": {
#               "subtype": [],
#               "name": "Booth School of Business",
#               "dbpedia_resource": "http://dbpedia.org/resource/Booth_School_of_Business"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "School of Social Service Administration",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "CollegeUniversity",
#                 "University"
#               ],
#               "name": "University of Chicago School of Social Service Administration",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_School_of_Social_Service_Administration"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Harris School of Public Policy Studies",
#             "disambiguation": {
#               "subtype": [
#                 "University"
#               ],
#               "name": "Harris School of Public Policy Studies",
#               "dbpedia_resource": "http://dbpedia.org/resource/Harris_School_of_Public_Policy_Studies"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Divinity School",
#             "disambiguation": {
#               "subtype": [
#                 "CollegeUniversity",
#                 "Company",
#                 "University"
#               ],
#               "name": "University of Chicago Divinity School",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_Divinity_School"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Graham School of Continuing Liberal"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "know",
#           "tense": "past"
#         },
#         "text": "known",
#         "normalized": "know"
#       }
#     },
#     {
#       "subject": {
#         "text": "the Pritzker School of Medicine, the Booth School of Business, the Law School, the School of Social Service Administration, the Harris School of Public Policy Studies, the Divinity School and the Graham School of Continuing Liberal and Professional Studies",
#         "keywords": [
#           {
#             "text": "Social Service Administration"
#           },
#           {
#             "text": "Public Policy Studies"
#           },
#           {
#             "text": "Pritzker School"
#           },
#           {
#             "text": "Continuing Liberal"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "Pritzker School of Medicine",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "CollegeUniversity",
#                 "University"
#               ],
#               "name": "Pritzker School of Medicine",
#               "dbpedia_resource": "http://dbpedia.org/resource/Pritzker_School_of_Medicine"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Booth School of Business",
#             "disambiguation": {
#               "subtype": [],
#               "name": "Booth School of Business",
#               "dbpedia_resource": "http://dbpedia.org/resource/Booth_School_of_Business"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "School of Social Service Administration",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "CollegeUniversity",
#                 "University"
#               ],
#               "name": "University of Chicago School of Social Service Administration",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_School_of_Social_Service_Administration"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Harris School of Public Policy Studies",
#             "disambiguation": {
#               "subtype": [
#                 "University"
#               ],
#               "name": "Harris School of Public Policy Studies",
#               "dbpedia_resource": "http://dbpedia.org/resource/Harris_School_of_Public_Policy_Studies"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Divinity School",
#             "disambiguation": {
#               "subtype": [
#                 "CollegeUniversity",
#                 "Company",
#                 "University"
#               ],
#               "name": "University of Chicago Divinity School",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_Divinity_School"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Graham School of Continuing Liberal"
#           }
#         ]
#       },
#       "sentence": " Beyond the arts and sciences, Chicago is also well known for its professional schools, which include the Pritzker School of Medicine, the Booth School of Business, the Law School, the School of Social Service Administration, the Harris School of Public Policy Studies, the Divinity School and the Graham School of Continuing Liberal and Professional Studies.",
#       "object": {
#         "text": "its professional schools",
#         "keywords": [
#           {
#             "text": "professional schools"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "include",
#           "tense": "present"
#         },
#         "text": "include",
#         "normalized": "include"
#       }
#     },
#     {
#       "subject": {
#         "text": "The university",
#         "keywords": [
#           {
#             "text": "university"
#           }
#         ],
#         "entities": []
#       },
#       "sentence": " The university currently enrolls 5,971 undergraduate students and 16,016 students overall.[5]",
#       "object": {
#         "text": "5,971 undergraduate students and 16,016 students",
#         "keywords": [
#           {
#             "text": "undergraduate students"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "enroll",
#           "tense": "present"
#         },
#         "text": "enrolls",
#         "normalized": "enroll"
#       }
#     },
#     {
#       "subject": {
#         "text": "the Barack Obama Presidential Center",
#         "keywords": [
#           {
#             "text": "Barack Obama Presidential"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "Barack Obama Presidential Center"
#           }
#         ]
#       },
#       "sentence": " The university is also home to the University of Chicago Press, the largest university press in the United States.[16] With an estimated completion date of 2021, the Barack Obama Presidential Center will be housed at the university and include both the Obama presidential library and offices of the Obama Foundation.[17]",
#       "object": {
#         "text": "at the university",
#         "keywords": [
#           {
#             "text": "university"
#           }
#         ],
#         "entities": []
#       },
#       "action": {
#         "verb": {
#           "text": "house",
#           "tense": "future"
#         },
#         "text": "will be housed",
#         "normalized": "will be house"
#       }
#     },
#     {
#       "subject": {
#         "text": "both the Obama presidential library and offices of the Obama Foundation.[17]",
#         "keywords": [
#           {
#             "text": "Obama presidential library"
#           },
#           {
#             "text": "Obama Foundation."
#           },
#           {
#             "text": "offices"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Person",
#             "text": "Barack Obama",
#             "disambiguation": {
#               "subtype": [
#                 "Politician",
#                 "President",
#                 "Appointer",
#                 "AwardWinner",
#                 "Celebrity",
#                 "PoliticalAppointer",
#                 "U.S.Congressperson",
#                 "USPresident",
#                 "TVActor"
#               ],
#               "name": "Barack Obama",
#               "dbpedia_resource": "http://dbpedia.org/resource/Barack_Obama"
#             }
#           },
#           {
#             "type": "Organization",
#             "text": "Obama Foundation."
#           }
#         ]
#       },
#       "sentence": " The university is also home to the University of Chicago Press, the largest university press in the United States.[16] With an estimated completion date of 2021, the Barack Obama Presidential Center will be housed at the university and include both the Obama presidential library and offices of the Obama Foundation.[17]",
#       "object": {
#         "text": "the Barack Obama Presidential Center",
#         "keywords": [
#           {
#             "text": "Barack Obama Presidential"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "Barack Obama Presidential Center"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "include",
#           "tense": "present"
#         },
#         "text": "include",
#         "normalized": "include"
#       }
#     },
#     {
#       "subject": {
#         "text": "The University of Chicago",
#         "keywords": [
#           {
#             "text": "University"
#           },
#           {
#             "text": "Chicago"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "University of Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "Company",
#                 "PeriodicalPublisher",
#                 "CollegeUniversity"
#               ],
#               "name": "University of Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago"
#             }
#           }
#         ]
#       },
#       "sentence": " The University of Chicago has produced many prominent alumni, faculty members and researchers.",
#       "object": {
#         "text": "produced many prominent alumni, faculty members and researchers",
#         "keywords": [
#           {
#             "text": "prominent alumni"
#           },
#           {
#             "text": "faculty members"
#           },
#           {
#             "text": "researchers"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "have",
#           "tense": "present"
#         },
#         "text": "has",
#         "normalized": "have"
#       }
#     },
#     {
#       "subject": {
#         "text": "The University of Chicago",
#         "keywords": [
#           {
#             "text": "University"
#           },
#           {
#             "text": "Chicago"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "University of Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "Company",
#                 "PeriodicalPublisher",
#                 "CollegeUniversity"
#               ],
#               "name": "University of Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago"
#             }
#           }
#         ]
#       },
#       "sentence": " The University of Chicago has produced many prominent alumni, faculty members and researchers.",
#       "object": {
#         "text": "many prominent alumni, faculty members and researchers",
#         "keywords": [
#           {
#             "text": "prominent alumni"
#           },
#           {
#             "text": "faculty members"
#           },
#           {
#             "text": "researchers"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "produce",
#           "tense": "past"
#         },
#         "text": "has produced",
#         "normalized": "have produce"
#       }
#     },
#     {
#       "subject": {
#         "text": "been affiliated with the university as professors, students, faculty, or staff",
#         "keywords": [
#           {
#             "text": "professors"
#           },
#           {
#             "text": "university"
#           },
#           {
#             "text": "students"
#           },
#           {
#             "text": "faculty"
#           }
#         ],
#         "entities": []
#       },
#       "sentence": " As of October 2018, 98 Nobel laureates [18] have been affiliated with the university as professors, students, faculty, or staff, making it a university with one of the highest concentrations of Nobel laureates in the world.",
#       "action": {
#         "verb": {
#           "text": "have",
#           "tense": "present"
#         },
#         "text": "have",
#         "normalized": "have"
#       }
#     },
#     {
#       "subject": {
#         "text": "98 Nobel laureates [18]",
#         "keywords": [
#           {
#             "text": "Nobel"
#           }
#         ]
#       },
#       "sentence": " As of October 2018, 98 Nobel laureates [18] have been affiliated with the university as professors, students, faculty, or staff, making it a university with one of the highest concentrations of Nobel laureates in the world.",
#       "object": {
#         "text": "affiliated with the university as professors, students, faculty, or staff",
#         "keywords": [
#           {
#             "text": "professors"
#           },
#           {
#             "text": "university"
#           },
#           {
#             "text": "students"
#           },
#           {
#             "text": "faculty"
#           }
#         ],
#         "entities": []
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "past"
#         },
#         "text": "been",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "professors, students, faculty, or staff,",
#         "keywords": [
#           {
#             "text": "professors"
#           },
#           {
#             "text": "students"
#           },
#           {
#             "text": "faculty"
#           },
#           {
#             "text": "staff"
#           }
#         ]
#       },
#       "sentence": " As of October 2018, 98 Nobel laureates [18] have been affiliated with the university as professors, students, faculty, or staff, making it a university with one of the highest concentrations of Nobel laureates in the world.",
#       "object": {
#         "text": "a university",
#         "keywords": [
#           {
#             "text": "university"
#           }
#         ],
#         "entities": []
#       },
#       "action": {
#         "verb": {
#           "text": "make",
#           "tense": "present"
#         },
#         "text": "making",
#         "normalized": "make"
#       }
#     },
#     {
#       "subject": {
#         "text": "The University of Chicago",
#         "keywords": [
#           {
#             "text": "University"
#           },
#           {
#             "text": "Chicago"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "University of Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "Company",
#                 "PeriodicalPublisher",
#                 "CollegeUniversity"
#               ],
#               "name": "University of Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago"
#             }
#           }
#         ]
#       },
#       "sentence": " The University of Chicago was incorporated as a coeducational [30] institution in 1890 by the American Baptist Education Society, using $400,000 donated to the ABES to match a $600,000 donation from Baptist oil magnate and philanthropist John D. Rockefeller,[31] and including land donated by Marshall Field.[32] While the Rockefeller donation provided money for academic operations and long-term endowment, it was stipulated that such money could not be used for buildings.",
#       "object": {
#         "text": "incorporated"
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "past"
#         },
#         "text": "was",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "The University of Chicago",
#         "keywords": [
#           {
#             "text": "University"
#           },
#           {
#             "text": "Chicago"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "University of Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "Location",
#                 "Company",
#                 "PeriodicalPublisher",
#                 "CollegeUniversity"
#               ],
#               "name": "University of Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago"
#             }
#           }
#         ]
#       },
#       "sentence": " The University of Chicago was incorporated as a coeducational [30] institution in 1890 by the American Baptist Education Society, using $400,000 donated to the ABES to match a $600,000 donation from Baptist oil magnate and philanthropist John D. Rockefeller,[31] and including land donated by Marshall Field.[32] While the Rockefeller donation provided money for academic operations and long-term endowment, it was stipulated that such money could not be used for buildings.",
#       "action": {
#         "verb": {
#           "text": "incorporate",
#           "tense": "past"
#         },
#         "text": "was incorporated",
#         "normalized": "be incorporate"
#       }
#     },
#     {
#       "subject": {
#         "text": "$400,000 donated to the ABES",
#         "keywords": [
#           {
#             "text": "ABES"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Quantity",
#             "text": "$400,000"
#           }
#         ]
#       },
#       "sentence": " The University of Chicago was incorporated as a coeducational [30] institution in 1890 by the American Baptist Education Society, using $400,000 donated to the ABES to match a $600,000 donation from Baptist oil magnate and philanthropist John D. Rockefeller,[31] and including land donated by Marshall Field.[32] While the Rockefeller donation provided money for academic operations and long-term endowment, it was stipulated that such money could not be used for buildings.",
#       "object": {
#         "text": "to match a $600,000 donation from Baptist oil magnate and philanthropist John D. Rockefeller",
#         "keywords": [
#           {
#             "text": "Baptist oil magnate"
#           },
#           {
#             "text": "philanthropist John D."
#           },
#           {
#             "text": "Rockefeller"
#           },
#           {
#             "text": "donation"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Company",
#             "text": "Baptist oil"
#           },
#           {
#             "type": "Person",
#             "text": "John D. Rockefeller",
#             "disambiguation": {
#               "subtype": [
#                 "CompanyFounder"
#               ],
#               "name": "John D. Rockefeller",
#               "dbpedia_resource": "http://dbpedia.org/resource/John_D._Rockefeller"
#             }
#           },
#           {
#             "type": "Quantity",
#             "text": "$600,000"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "use",
#           "tense": "present"
#         },
#         "text": "using",
#         "normalized": "use"
#       }
#     },
#     {
#       "subject": {
#         "text": "$400,000",
#         "entities": [
#           {
#             "type": "Quantity",
#             "text": "$400,000"
#           }
#         ]
#       },
#       "sentence": " The University of Chicago was incorporated as a coeducational [30] institution in 1890 by the American Baptist Education Society, using $400,000 donated to the ABES to match a $600,000 donation from Baptist oil magnate and philanthropist John D. Rockefeller,[31] and including land donated by Marshall Field.[32] While the Rockefeller donation provided money for academic operations and long-term endowment, it was stipulated that such money could not be used for buildings.",
#       "object": {
#         "text": "to the ABES",
#         "keywords": [
#           {
#             "text": "ABES"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "donate",
#           "tense": "past"
#         },
#         "text": "donated",
#         "normalized": "donate"
#       }
#     },
#     {
#       "subject": {
#         "text": "by Marshall Field.",
#         "keywords": [
#           {
#             "text": "Marshall Field"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Facility",
#             "text": "Marshall Field."
#           }
#         ]
#       },
#       "sentence": " The University of Chicago was incorporated as a coeducational [30] institution in 1890 by the American Baptist Education Society, using $400,000 donated to the ABES to match a $600,000 donation from Baptist oil magnate and philanthropist John D. Rockefeller,[31] and including land donated by Marshall Field.[32] While the Rockefeller donation provided money for academic operations and long-term endowment, it was stipulated that such money could not be used for buildings.",
#       "object": {
#         "text": "land",
#         "keywords": [
#           {
#             "text": "land"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "donate",
#           "tense": "past"
#         },
#         "text": "donated",
#         "normalized": "donate"
#       }
#     },
#     {
#       "subject": {
#         "text": "the Rockefeller donation",
#         "keywords": [
#           {
#             "text": "Rockefeller donation"
#           }
#         ]
#       },
#       "sentence": " The University of Chicago was incorporated as a coeducational [30] institution in 1890 by the American Baptist Education Society, using $400,000 donated to the ABES to match a $600,000 donation from Baptist oil magnate and philanthropist John D. Rockefeller,[31] and including land donated by Marshall Field.[32] While the Rockefeller donation provided money for academic operations and long-term endowment, it was stipulated that such money could not be used for buildings.",
#       "object": {
#         "text": "money",
#         "keywords": [
#           {
#             "text": "money"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "provide",
#           "tense": "past"
#         },
#         "text": "provided",
#         "normalized": "provide"
#       }
#     },
#     {
#       "subject": {
#         "text": "it"
#       },
#       "sentence": " The University of Chicago was incorporated as a coeducational [30] institution in 1890 by the American Baptist Education Society, using $400,000 donated to the ABES to match a $600,000 donation from Baptist oil magnate and philanthropist John D. Rockefeller,[31] and including land donated by Marshall Field.[32] While the Rockefeller donation provided money for academic operations and long-term endowment, it was stipulated that such money could not be used for buildings.",
#       "object": {
#         "text": "that such money could not be used for buildings",
#         "keywords": [
#           {
#             "text": "money"
#           },
#           {
#             "text": "buildings"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Facility",
#             "text": "Classics Building"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "stipulate",
#           "tense": "past"
#         },
#         "text": "was stipulated",
#         "normalized": "be stipulate"
#       }
#     },
#     {
#       "subject": {
#         "text": "The Hyde Park campus",
#         "keywords": [
#           {
#             "text": "Hyde Park campus"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Facility",
#             "text": "Hyde Park"
#           }
#         ]
#       },
#       "sentence": " The Hyde Park campus was financed by donations from wealthy Chicagoans like Silas B. Cobb who provided the funds for the campus' first building, Cobb Lecture Hall, and matched Marshall Field's pledge of $100,000.",
#       "object": {
#         "text": "financed by donations from wealthy Chicagoans like Silas B. Cobb who provided the funds for the campus' first building, Cobb Lecture Hall, and matched Marshall Field's pledge of $100,000",
#         "keywords": [
#           {
#             "text": "Silas B. Cobb"
#           },
#           {
#             "text": "Cobb Lecture Hall"
#           },
#           {
#             "text": "wealthy Chicagoans"
#           },
#           {
#             "text": "Marshall Field"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Person",
#             "text": "Silas B. Cobb"
#           },
#           {
#             "type": "Facility",
#             "text": "Christ Church Hall."
#           },
#           {
#             "type": "Facility",
#             "text": "Cobb Lecture Hall"
#           },
#           {
#             "type": "Person",
#             "text": "Marshall Field",
#             "disambiguation": {
#               "subtype": [
#                 "CompanyFounder"
#               ],
#               "name": "Marshall Field",
#               "dbpedia_resource": "http://dbpedia.org/resource/Marshall_Field"
#             }
#           },
#           {
#             "type": "Quantity",
#             "text": "$100,000"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "be",
#           "tense": "past"
#         },
#         "text": "was",
#         "normalized": "be"
#       }
#     },
#     {
#       "subject": {
#         "text": "The Hyde Park campus",
#         "keywords": [
#           {
#             "text": "Hyde Park campus"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Facility",
#             "text": "Hyde Park"
#           }
#         ]
#       },
#       "sentence": " The Hyde Park campus was financed by donations from wealthy Chicagoans like Silas B. Cobb who provided the funds for the campus' first building, Cobb Lecture Hall, and matched Marshall Field's pledge of $100,000.",
#       "object": {
#         "text": "by donations from wealthy Chicagoans like Silas B. Cobb who provided the funds for the campus' first building, Cobb Lecture Hall, and matched Marshall Field's pledge of $100,000",
#         "keywords": [
#           {
#             "text": "Silas B. Cobb"
#           },
#           {
#             "text": "Cobb Lecture Hall"
#           },
#           {
#             "text": "wealthy Chicagoans"
#           },
#           {
#             "text": "Marshall Field"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Person",
#             "text": "Silas B. Cobb"
#           },
#           {
#             "type": "Facility",
#             "text": "Christ Church Hall."
#           },
#           {
#             "type": "Facility",
#             "text": "Cobb Lecture Hall"
#           },
#           {
#             "type": "Person",
#             "text": "Marshall Field",
#             "disambiguation": {
#               "subtype": [
#                 "CompanyFounder"
#               ],
#               "name": "Marshall Field",
#               "dbpedia_resource": "http://dbpedia.org/resource/Marshall_Field"
#             }
#           },
#           {
#             "type": "Quantity",
#             "text": "$100,000"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "finance",
#           "tense": "past"
#         },
#         "text": "was financed",
#         "normalized": "be finance"
#       }
#     },
#     {
#       "subject": {
#         "text": "the funds",
#         "keywords": [
#           {
#             "text": "funds"
#           }
#         ]
#       },
#       "sentence": " The Hyde Park campus was financed by donations from wealthy Chicagoans like Silas B. Cobb who provided the funds for the campus' first building, Cobb Lecture Hall, and matched Marshall Field's pledge of $100,000.",
#       "object": {
#         "text": "for the campus' first building",
#         "keywords": [
#           {
#             "text": "campus"
#           },
#           {
#             "text": "building"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Facility",
#             "text": "Christ Church Hall."
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "provide",
#           "tense": "past"
#         },
#         "text": "provided",
#         "normalized": "provide"
#       }
#     },
#     {
#       "subject": {
#         "text": "businessmen Charles L. Hutchinson (trustee, treasurer and donor of Hutchinson Commons), Martin A. Ryerson (president of the board of trustees and donor of the Ryerson Physical Laboratory) Adolphus Clay Bartlett and Leon Mandel, who funded the construction of the gymnasium and assembly hall, and George C. Walker of the Walker Museum, a relative of Cobb who encouraged his inaugural donation for facilities.[33]",
#         "keywords": [
#           {
#             "text": "Martin A. Ryerson"
#           },
#           {
#             "text": "Ryerson Physical Laboratory"
#           },
#           {
#             "text": "Charles L. Hutchinson"
#           },
#           {
#             "text": "Adolphus Clay Bartlett"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Person",
#             "text": "Charles L. Hutchinson"
#           },
#           {
#             "type": "JobTitle",
#             "text": "trustee"
#           },
#           {
#             "type": "JobTitle",
#             "text": "treasurer"
#           },
#           {
#             "type": "Organization",
#             "text": "Hutchinson Commons"
#           },
#           {
#             "type": "Person",
#             "text": "Martin A. Ryerson"
#           },
#           {
#             "type": "JobTitle",
#             "text": "president of the board"
#           },
#           {
#             "type": "Facility",
#             "text": "Ryerson Physical Laboratory"
#           },
#           {
#             "type": "Person",
#             "text": "Adolphus Clay Bartlett"
#           },
#           {
#             "type": "Person",
#             "text": "Leon Mandel"
#           },
#           {
#             "type": "Facility",
#             "text": "assembly hall"
#           },
#           {
#             "type": "Person",
#             "text": "George C. Walker"
#           },
#           {
#             "type": "Facility",
#             "text": "Walker Museum"
#           },
#           {
#             "type": "Person",
#             "text": "Silas B. Cobb"
#           }
#         ]
#       },
#       "sentence": " Other early benefactors included businessmen Charles L. Hutchinson (trustee, treasurer and donor of Hutchinson Commons), Martin A. Ryerson (president of the board of trustees and donor of the Ryerson Physical Laboratory) Adolphus Clay Bartlett and Leon Mandel, who funded the construction of the gymnasium and assembly hall, and George C. Walker of the Walker Museum, a relative of Cobb who encouraged his inaugural donation for facilities.[33]",
#       "object": {
#         "text": "Other early benefactors",
#         "keywords": [
#           {
#             "text": "early benefactors"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "include",
#           "tense": "past"
#         },
#         "text": "included",
#         "normalized": "include"
#       }
#     },
#     {
#       "subject": {
#         "text": "Adolphus Clay Bartlett and Leon Mandel",
#         "keywords": [
#           {
#             "text": "Adolphus Clay Bartlett"
#           },
#           {
#             "text": "Leon Mandel"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Person",
#             "text": "Adolphus Clay Bartlett"
#           },
#           {
#             "type": "Person",
#             "text": "Leon Mandel"
#           }
#         ]
#       },
#       "sentence": " Other early benefactors included businessmen Charles L. Hutchinson (trustee, treasurer and donor of Hutchinson Commons), Martin A. Ryerson (president of the board of trustees and donor of the Ryerson Physical Laboratory) Adolphus Clay Bartlett and Leon Mandel, who funded the construction of the gymnasium and assembly hall, and George C. Walker of the Walker Museum, a relative of Cobb who encouraged his inaugural donation for facilities.[33]",
#       "object": {
#         "text": "the construction of the gymnasium",
#         "keywords": [
#           {
#             "text": "gymnasium"
#           },
#           {
#             "text": "construction"
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "fund",
#           "tense": "past"
#         },
#         "text": "funded",
#         "normalized": "fund"
#       }
#     },
#     {
#       "subject": {
#         "text": "The Hyde Park campus",
#         "keywords": [
#           {
#             "text": "Hyde Park campus"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Facility",
#             "text": "Hyde Park"
#           }
#         ]
#       },
#       "sentence": " The Hyde Park campus continued the legacy of the original university of the same name, which had closed in 1880s after its campus was foreclosed on.[34] What became known as the Old University of Chicago had been founded by a small group of Baptist educators in 1856 through a land endowment from Senator Stephen A. Douglas.",
#       "object": {
#         "text": "the legacy of the original university of the same name, which had closed in 1880s after its campus was foreclosed on.[34] What became known as the Old University of Chicago had been founded by a small group of Baptist educators in 1856 through a land endowment from Senator Stephen A. Douglas",
#         "keywords": [
#           {
#             "text": "Senator Stephen A."
#           },
#           {
#             "text": "land endowment"
#           },
#           {
#             "text": "Baptist educators"
#           },
#           {
#             "text": "small group"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Facility",
#             "text": "Christ Church Hall."
#           },
#           {
#             "type": "Organization",
#             "text": "Old University of Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "CollegeUniversity"
#               ],
#               "name": "Old University of Chicago",
#               "dbpedia_resource": "http://dbpedia.org/resource/Old_University_of_Chicago"
#             }
#           },
#           {
#             "type": "Person",
#             "text": "Senator Stephen A. Douglas",
#             "disambiguation": {
#               "subtype": [
#                 "Politician",
#                 "U.S.Congressperson"
#               ],
#               "name": "Stephen A. Douglas",
#               "dbpedia_resource": "http://dbpedia.org/resource/Stephen_A._Douglas"
#             }
#           }
#         ]
#       },
#       "action": {
#         "verb": {
#           "text": "continue",
#           "tense": "past"
#         },
#         "text": "continued",
#         "normalized": "continue"
#       }
#     },
#     {
#       "subject": {
#         "text": "the Old University of Chicago",
#         "keywords": [
#           {
#             "text": "Old University"
#           },
#           {
#             "text": "Chicago"
#           }
#         ],
#         "entities": [
#           {
#             "type": "Organization",
#             "text": "Old University of Chicago",
#             "disambiguation": {
#               "subtype": [
#                 "CollegeUniversity"
# ...
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.317908,
#       "emotion": {
#         "sadness": 0.046269,
#         "joy": 0.270597,
#         "fear": 0.051791,
#         "disgust": 0.24006,
#         "anger": 0.09495
#       },
#       "count": 1
#     },
#     {
#       "type": "Location",
#       "text": "Illinois",
#       "sentiment": {
#         "score": 0.312495,
#         "label": "positive"
#       },
#       "relevance": 0.317593,
#       "emotion": {
#         "sadness": 0.119057,
#         "joy": 0.558697,
#         "fear": 0.053032,
#         "disgust": 0.046654,
#         "anger": 0.036484
#       },
#       "disambiguation": {
#         "subtype": [
#           "PoliticalDistrict",
#           "AdministrativeDivision",
#           "GovernmentalJurisdiction",
#           "USState",
#           "StateOrCounty"
#         ],
#         "name": "Illinois",
#         "dbpedia_resource": "http://dbpedia.org/resource/Illinois"
#       },
#       "count": 4
#     },
#     {
#       "type": "Organization",
#       "text": "University of Chicago Presents",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.316543,
#       "emotion": {
#         "sadness": 0.077059,
#         "joy": 0.639024,
#         "fear": 0.081485,
#         "disgust": 0.027192,
#         "anger": 0.079795
#       },
#       "count": 1
#     },
#     {
#       "type": "Facility",
#       "text": "Argonne National Laboratory",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.313765,
#       "emotion": {
#         "sadness": 0.023943,
#         "joy": 0.851896,
#         "fear": 0.010551,
#         "disgust": 0.081621,
#         "anger": 0.061004
#       },
#       "count": 5
#     },
#     {
#       "type": "PrintMedia",
#       "text": "New York Times",
#       "sentiment": {
#         "score": 0.433258,
#         "label": "positive"
#       },
#       "relevance": 0.301513,
#       "emotion": {
#         "sadness": 0.034386,
#         "joy": 0.738046,
#         "fear": 0.024995,
#         "disgust": 0.084781,
#         "anger": 0.146204
#       },
#       "disambiguation": {
#         "subtype": [
#           "Organization",
#           "Company",
#           "AwardPresentingOrganization",
#           "AwardWinner",
#           "CompanyShareholder",
#           "Newspaper"
#         ],
#         "name": "The New York Times",
#         "dbpedia_resource": "http://dbpedia.org/resource/The_New_York_Times"
#       },
#       "count": 5
#     },
#     {
#       "type": "Organization",
#       "text": "Stetson University",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.301014,
#       "emotion": {
#         "sadness": 0.144548,
#         "joy": 0.185315,
#         "fear": 0.087573,
#         "disgust": 0.077654,
#         "anger": 0.090723
#       },
#       "disambiguation": {
#         "subtype": [
#           "CollegeUniversity",
#           "University"
#         ],
#         "name": "Stetson University",
#         "dbpedia_resource": "http://dbpedia.org/resource/Stetson_University"
#       },
#       "count": 1
#     },
#     {
#       "type": "Person",
#       "text": "Barack Obama",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.299613,
#       "emotion": {
#         "sadness": 0.144548,
#         "joy": 0.185315,
#         "fear": 0.087573,
#         "disgust": 0.077654,
#         "anger": 0.090723
#       },
#       "disambiguation": {
#         "subtype": [
#           "Politician",
#           "President",
#           "Appointer",
#           "AwardWinner",
#           "Celebrity",
#           "PoliticalAppointer",
#           "U.S.Congressperson",
#           "USPresident",
#           "TVActor"
#         ],
#         "name": "Barack Obama",
#         "dbpedia_resource": "http://dbpedia.org/resource/Barack_Obama"
#       },
#       "count": 4
#     },
#     {
#       "type": "Organization",
#       "text": "Northwestern University",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.297904,
#       "emotion": {
#         "sadness": 0.140665,
#         "joy": 0.225077,
#         "fear": 0.065905,
#         "disgust": 0.065031,
#         "anger": 0.081147
#       },
#       "disambiguation": {
#         "subtype": [
#           "AwardPresentingOrganization",
#           "CollegeUniversity",
#           "University"
#         ],
#         "name": "Northwestern University",
#         "dbpedia_resource": "http://dbpedia.org/resource/Northwestern_University"
#       },
#       "count": 1
#     },
#     {
#       "type": "Location",
#       "text": "United States.",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.296054,
#       "emotion": {
#         "sadness": 0.0,
#         "joy": 0.0,
#         "fear": 0.0,
#         "disgust": 0.0,
#         "anger": 0.0
#       },
#       "disambiguation": {
#         "subtype": [
#           "Country"
#         ]
#       },
#       "count": 4
#     },
#     {
#       "type": "Organization",
#       "text": "university Commons",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.293811,
#       "emotion": {
#         "sadness": 0.0,
#         "joy": 0.0,
#         "fear": 0.0,
#         "disgust": 0.0,
#         "anger": 0.0
#       },
#       "count": 1
#     },
#     {
#       "type": "Organization",
#       "text": "University of Cambridge",
#       "sentiment": {
#         "score": -0.302793,
#         "label": "negative"
#       },
#       "relevance": 0.292904,
#       "emotion": {
#         "sadness": 0.280667,
#         "joy": 0.470506,
#         "fear": 0.044809,
#         "disgust": 0.072691,
#         "anger": 0.123286
#       },
#       "disambiguation": {
#         "subtype": [
#           "Location",
#           "CollegeUniversity",
#           "ProcessorManufacturer",
#           "University"
#         ],
#         "name": "University of Cambridge",
#         "dbpedia_resource": "http://dbpedia.org/resource/University_of_Cambridge"
#       },
#       "count": 1
#     },
#     {
#       "type": "Organization",
#       "text": "Harris School of Public Policy Studies",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.291871,
#       "emotion": {
#         "sadness": 0.072119,
#         "joy": 0.315062,
#         "fear": 0.078728,
#         "disgust": 0.114538,
#         "anger": 0.160434
#       },
#       "disambiguation": {
#         "subtype": [
#           "University"
#         ],
#         "name": "Harris School of Public Policy Studies",
#         "dbpedia_resource": "http://dbpedia.org/resource/Harris_School_of_Public_Policy_Studies"
#       },
#       "count": 2
#     },
#     {
#       "type": "Organization",
#       "text": "University of Oxford.",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.290947,
#       "emotion": {
#         "sadness": 0.057107,
#         "joy": 0.365073,
#         "fear": 0.0636,
#         "disgust": 0.086632,
#         "anger": 0.069455
#       },
#       "count": 1
#     },
#     {
#       "type": "Person",
#       "text": "Alonzo Stagg",
#       "sentiment": {
#         "score": 0.0,
#         "label": "neutral"
#       },
#       "relevance": 0.289198,
#       "emotion": {
#         "sadness": 0.076551,
#         "joy": 0.439949,
#         "fear": 0.018495,
#         "disgust": 0.429771,
#         "anger": 0.118895
#       },
#       "count": 4
#     }
#   ],
#   "emotion": {
#     "document": {
#       "emotion": {
#         "sadness": 0.11667,
#         "joy": 0.49401,
#         "fear": 0.083797,
#         "disgust": 0.07107,
#         "anger": 0.06588
#       }
#     }
#   },
#   "concepts": [
#     {
#       "text": "University of Chicago",
#       "relevance": 0.881964,
#       "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago"
#     },
#     {
#       "text": "Chicago",
#       "relevance": 0.259157,
#       "dbpedia_resource": "http://dbpedia.org/resource/Chicago"
#     },
#     {
#       "text": "Nobel Prize",
#       "relevance": 0.188455,
#       "dbpedia_resource": "http://dbpedia.org/resource/Nobel_Prize"
#     },
#     {
#       "text": "Hyde Park, Chicago",
#       "relevance": 0.1876,
#       "dbpedia_resource": "http://dbpedia.org/resource/Hyde_Park,_Chicago"
#     },
#     {
#       "text": "Association of American Universities",
#       "relevance": 0.172137,
#       "dbpedia_resource": "http://dbpedia.org/resource/Association_of_American_Universities"
#     },
#     {
#       "text": "University",
#       "relevance": 0.163781,
#       "dbpedia_resource": "http://dbpedia.org/resource/University"
#     },
#     {
#       "text": "Illinois",
#       "relevance": 0.158548,
#       "dbpedia_resource": "http://dbpedia.org/resource/Illinois"
#     },
#     {
#       "text": "National Association of Independent Colleges and Universities",
#       "relevance": 0.157287,
#       "dbpedia_resource": "http://dbpedia.org/resource/National_Association_of_Independent_Colleges_and_Universities"
#     },
#     {
#       "text": "College",
#       "relevance": 0.153547,
#       "dbpedia_resource": "http://dbpedia.org/resource/College"
#     },
#     {
#       "text": "Argonne National Laboratory",
#       "relevance": 0.147086,
#       "dbpedia_resource": "http://dbpedia.org/resource/Argonne_National_Laboratory"
#     },
#     {
#       "text": "University of Chicago Booth School of Business",
#       "relevance": 0.146426,
#       "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_Booth_School_of_Business"
#     },
#     {
#       "text": "Barack Obama",
#       "relevance": 0.140972,
#       "dbpedia_resource": "http://dbpedia.org/resource/Barack_Obama"
#     },
#     {
#       "text": "Chicago Maroons",
#       "relevance": 0.138581,
#       "dbpedia_resource": "http://dbpedia.org/resource/Chicago_Maroons"
#     },
#     {
#       "text": "University of Chicago Law School",
#       "relevance": 0.134764,
#       "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_Law_School"
#     },
#     {
#       "text": "Ivy League",
#       "relevance": 0.132047,
#       "dbpedia_resource": "http://dbpedia.org/resource/Ivy_League"
#     },
#     {
#       "text": "Doctorate",
#       "relevance": 0.128494,
#       "dbpedia_resource": "http://dbpedia.org/resource/Doctorate"
#     },
#     {
#       "text": "Big Ten Conference",
#       "relevance": 0.128101,
#       "dbpedia_resource": "http://dbpedia.org/resource/Big_Ten_Conference"
#     },
#     {
#       "text": "Public university",
#       "relevance": 0.128082,
#       "dbpedia_resource": "http://dbpedia.org/resource/Public_university"
#     },
#     {
#       "text": "Rector",
#       "relevance": 0.125145,
#       "dbpedia_resource": "http://dbpedia.org/resource/Rector"
#     },
#     {
#       "text": "University of Chicago Divinity School",
#       "relevance": 0.122967,
#       "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_Divinity_School"
#     },
#     {
#       "text": "South Campus Residence Hall",
#       "relevance": 0.121392,
#       "dbpedia_resource": "http://dbpedia.org/resource/South_Campus_Residence_Hall"
#     },
#     {
#       "text": "University of Chicago Scavenger Hunt",
#       "relevance": 0.119165,
#       "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_Scavenger_Hunt"
#     },
#     {
#       "text": "Types of universities and colleges",
#       "relevance": 0.118108,
#       "dbpedia_resource": "http://dbpedia.org/resource/Types_of_universities_and_colleges"
#     },
#     {
#       "text": "The Chicago Maroon",
#       "relevance": 0.117573,
#       "dbpedia_resource": "http://dbpedia.org/resource/The_Chicago_Maroon"
#     },
#     {
#       "text": "Enrico Fermi",
#       "relevance": 0.11746,
#       "dbpedia_resource": "http://dbpedia.org/resource/Enrico_Fermi"
#     },
#     {
#       "text": "University Athletic Association",
#       "relevance": 0.114773,
#       "dbpedia_resource": "http://dbpedia.org/resource/University_Athletic_Association"
#     },
#     {
#       "text": "Yale University",
#       "relevance": 0.108994,
#       "dbpedia_resource": "http://dbpedia.org/resource/Yale_University"
#     },
#     {
#       "text": "University of Cambridge",
#       "relevance": 0.108277,
#       "dbpedia_resource": "http://dbpedia.org/resource/University_of_Cambridge"
#     },
#     {
#       "text": "Chancellor",
#       "relevance": 0.107852,
#       "dbpedia_resource": "http://dbpedia.org/resource/Chancellor_(education)"
#     },
#     {
#       "text": "Committee on Institutional Cooperation",
#       "relevance": 0.107597,
#       "dbpedia_resource": "http://dbpedia.org/resource/Committee_on_Institutional_Cooperation"
#     },
#     {
#       "text": "Northwestern University",
#       "relevance": 0.107545,
#       "dbpedia_resource": "http://dbpedia.org/resource/Northwestern_University"
#     },
#     {
#       "text": "Chicago Loop",
#       "relevance": 0.10343,
#       "dbpedia_resource": "http://dbpedia.org/resource/Chicago_Loop"
#     },
#     {
#       "text": "University of Chicago Laboratory Schools",
#       "relevance": 0.103418,
#       "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_Laboratory_Schools"
#     },
#     {
#       "text": "Harris School of Public Policy Studies",
#       "relevance": 0.1024,
#       "dbpedia_resource": "http://dbpedia.org/resource/Harris_School_of_Public_Policy_Studies"
#     },
#     {
#       "text": "Milton Friedman",
#       "relevance": 0.10085,
#       "dbpedia_resource": "http://dbpedia.org/resource/Milton_Friedman"
#     },
#     {
#       "text": "Graduate school",
#       "relevance": 0.0962819,
#       "dbpedia_resource": "http://dbpedia.org/resource/Graduate_school"
#     },
#     {
#       "text": "President of the United States",
#       "relevance": 0.0958485,
#       "dbpedia_resource": "http://dbpedia.org/resource/President_of_the_United_States"
#     },
#     {
#       "text": "Walter Netsch",
#       "relevance": 0.0948392,
#       "dbpedia_resource": "http://dbpedia.org/resource/Walter_Netsch"
#     },
#     {
#       "text": "Chicago Pile-1",
#       "relevance": 0.093731,
#       "dbpedia_resource": "http://dbpedia.org/resource/Chicago_Pile-1"
#     },
#     {
#       "text": "Midway Plaisance",
#       "relevance": 0.0933775,
#       "dbpedia_resource": "http://dbpedia.org/resource/Midway_Plaisance"
#     },
#     {
#       "text": "Robert Zimmer",
#       "relevance": 0.0924983,
#       "dbpedia_resource": "http://dbpedia.org/resource/Robert_Zimmer"
#     },
#     {
#       "text": "Chicago school",
#       "relevance": 0.091375,
#       "dbpedia_resource": "http://dbpedia.org/resource/Chicago_school_(sociology)"
#     },
#     {
#       "text": "Academic Ranking of World Universities",
#       "relevance": 0.091081,
#       "dbpedia_resource": "http://dbpedia.org/resource/Academic_Ranking_of_World_Universities"
#     },
#     {
#       "text": "Woodlawn, Chicago",
#       "relevance": 0.0897281,
#       "dbpedia_resource": "http://dbpedia.org/resource/Woodlawn,_Chicago"
#     },
#     {
#       "text": "Hanna Holborn Gray",
#       "relevance": 0.0897006,
#       "dbpedia_resource": "http://dbpedia.org/resource/Hanna_Holborn_Gray"
#     },
#     {
#       "text": "South Side",
#       "relevance": 0.0892598,
#       "dbpedia_resource": "http://dbpedia.org/resource/South_Side_(Chicago)"
#     },
#     {
#       "text": "Robert Maynard Hutchins",
#       "relevance": 0.0884704,
#       "dbpedia_resource": "http://dbpedia.org/resource/Robert_Maynard_Hutchins"
#     },
#     {
#       "text": "University of Chicago Medical Center",
#       "relevance": 0.0880094,
#       "dbpedia_resource": "http://dbpedia.org/resource/University_of_Chicago_Medical_Center"
#     },
#     {
#       "text": "North Central Association of Colleges and Schools",
#       "relevance": 0.0873057,
#       "dbpedia_resource": "http://dbpedia.org/resource/North_Central_Association_of_Colleges_and_Schools"
#     },
#     {
#       "text": "Business school",
#       "relevance": 0.0868822,
#       "dbpedia_resource": "http://dbpedia.org/resource/Business_school"
#     }
#   ],
#   "categories": [
#     {
#       "score": 0.442876,
#       "label": "/education/school"
#     },
#     {
#       "score": 0.395677,
#       "label": "/education/graduate school/college"
#     },
#     {
#       "score": 0.388779,
#       "label": "/technology and computing/software/databases"
#     }
#   ],
#   "warnings": [
#     "Text content exceeds 50000 character limit. Only first 50000 characters processed..."
#   ]
# }

# %% [markdown]
# ## Running Tweets through NLU

# %%
directory = 'C://Users//IBM_ADMIN//Documents//Teaching//Data Projects//Text//Tweets//'
    
file = 'jeep_new.txt'
path = directory + file

# %%
tweets = pd.read_csv(path,sep='\t', names = ['id', 'lang', 'created_at', 'screen_name', \
                                                       'name', 'location', 'retweet_count', 'text'])

tweets = tweets[tweets['text'].str.contains("love|hate", case=False)==True]

tweets = tweets.sample(n=1000)

# %%
tweets.head(5)
# Out:
#                  id lang                      created_at      screen_name  \
# 32119  9.228920e+17   en  Tue Oct 24 18:26:14 +0000 2017      krisvockler
# 39413  9.225192e+17   en  Mon Oct 23 17:44:55 +0000 2017      RoccoLaDuca
# 12311  9.227325e+17   en  Tue Oct 24 07:52:16 +0000 2017         HCLifeTX
# 64197  9.224475e+17   en  Mon Oct 23 13:00:06 +0000 2017  shwetap42680702
# 47925  9.218857e+17   en  Sat Oct 21 23:47:24 +0000 2017          JLA0104
#
#                     name            location  retweet_count  \
# 32119       Kris Vockler  Vancouver, WA, USA            0.0
# 39413       Rocco LaDuca           Utica, NY            0.0
# 12311  Hill Country Life          Texas, USA            0.0
# 64197     @Shweta_Pathak    New Delhi, India            0.0
# 47925                JLA        Marietta, GA            0.0
#
#                                                     text
# 32119  Bob loves a good sunrise. #teamfastncurious #r...
# 39413  FYI: What about gloves, goggles &amp; mask in ...
# 12311  RT @JeepsiesBlog: Baby Jeep stacking! For the ...
# 64197  RT @loveysparkz: ZAIN LOOKS SO FREAKING HOT DR...
# 47925  Lovin this GA Jeep Weather!!!    🍂🍁🍂🍁🍂🍁 #welco...

# %%
#Take a small sample
#tweets_eng = tweets[tweets['lang']=='en'].reset_index(drop=True).sample(frac=0.01, replace=True)
tweets_eng = tweets[tweets['lang']=='en'].reset_index(drop=True).head(10)

# %%
len(tweets_eng)
# Out:
# 10

# %%
# For NLU we DO NOT have to remove special characters to avoid problems with analysis
tweets_eng['text_clean'] = tweets_eng['text'].map(lambda x: re.sub('[^a-zA-Z0-9 @ . , : - _]', '', str(x)))

# %%
pd.set_option('display.max_colwidth', 150)
pd.set_option('display.max_rows', 10)
tweets_eng[['text']].head(5)
# Out:
#                                                                                                                                            text
# 0            Bob loves a good sunrise. #teamfastncurious #rebellerally #adventure #outdoorwomen #adventure4x4 #offroad… https://t.co/jVWgaumuvo
# 1          FYI: What about gloves, goggles &amp; mask in car? Adam says he bought them to change a rusty part under his old Jeep #ConleyRetrial
# 2  RT @JeepsiesBlog: Baby Jeep stacking! For the win! Love this photo by @Kirby98tj Teach 'em young! #jeepmafia #jeepkids https://t.co/0m9Tuuk…
# 3                  RT @loveysparkz: ZAIN LOOKS SO FREAKING HOT DRIVING THE JEEP!! I CAN'T HANDLE ITT 😍😍😍😭😭😭 #naamkarann https://t.co/wJfCQY73G0
# 4                                   Lovin this GA Jeep Weather!!!    🍂🍁🍂🍁🍂🍁 #welcomefall #fall #jeep #galove #topless 🚙 https://t.co/duP8naJkJr

# %%
# Read individual columns
raw_id = tweets_eng["id"].values
raw_text = tweets_eng["text"].values

# %%
raw_text
# Out:
# array(['Bob loves a good sunrise. #teamfastncurious #rebellerally #adventure #outdoorwomen #adventure4x4 #offroad… https://t.co/jVWgaumuvo',
#        'FYI: What about gloves, goggles &amp; mask in car? Adam says he bought them to change a rusty part under his old Jeep #ConleyRetrial',
#        "RT @JeepsiesBlog: Baby Jeep stacking! For the win! Love this photo by @Kirby98tj Teach 'em young! #jeepmafia #jeepkids https://t.co/0m9Tuuk…",
#        "RT @loveysparkz: ZAIN LOOKS SO FREAKING HOT DRIVING THE JEEP!! I CAN'T HANDLE ITT 😍😍😍😭😭😭 #naamkarann https://t.co/wJfCQY73G0",
#        'Lovin this GA Jeep Weather!!!    🍂🍁🍂🍁🍂🍁 #welcomefall #fall #jeep #galove #topless 🚙 https://t.co/duP8naJkJr',
#        '#JustForYouSweepstakes @sprint I would love to win the Jeep ☺',
#        '@sprint Would love to drive a 2018 Jeep Cherokee Overland to the Grand Canyon!!! #JustForYouSweepstakes',
#        'Love my Jeep but get tired of replacing 💩 on it. 😒',
#        'RT @zachkossick: I love my jeep but fucking god is it slow as shit',
#        'I liked a @YouTube video https://t.co/plhSQ4P9RW 10 things we HATE about our SRT8 Jeep'],
#       dtype=object)

# %%
# Set up lists to collect sentiments, and scores
sentiment_list = []
score_list = []

# carry over existing values
tweet_id = []
tweet_list = []

# %%
count = 0
for raw_id, raw_text in \
zip(raw_id, raw_text):
    response = natural_language_understanding.analyze(
        language = "en", #do not NLU to guess language on Tweets
        text=raw_text,
        
            features = Features(
                        #entities = EntitiesOptions(sentiment = True, emotion = True),
                        #keywords = KeywordsOptions(sentiment = True, emotion = True),
                        #concepts = ConceptsOptions(limit = 50),
                        #relations = RelationsOptions(),
                        sentiment = SentimentOptions(),
                        #semantic_roles = SemanticRolesOptions(entities = True, keywords = True),
                        #emotion = EmotionOptions(),
                        #categories = CategoriesOptions()
            )).get_result()

    if "label" in response["sentiment"]["document"]:
        sentiment_list.append(str(response["sentiment"]["document"]["label"]))
    else:
        sentiment_list.append("NA") 

    if "score" in response["sentiment"]["document"]:
        score_list.append(str(response["sentiment"]["document"]["score"]))
    else:
        score_list.append("0") 

    tweet_list.append(raw_text)
    tweet_id.append(raw_id)
    #print(count)
    #print(tweet_list)
    #print(tweet_id)
    count += 1

# %% [markdown]
# #### Dealing with nested JSONs

# %%
response
# Out:
# {'usage': {'text_units': 1, 'text_characters': 86, 'features': 1},
#  'sentiment': {'document': {'score': -0.809025, 'label': 'negative'}},
#  'language': 'en'}

# %%
response["sentiment"]
# Out:
# {'document': {'score': -0.809025, 'label': 'negative'}}

# %%
response["sentiment"]["document"]
# Out:
# {'score': -0.809025, 'label': 'negative'}

# %%
response["sentiment"]["document"]["label"]
# Out:
# 'negative'

# %%
response["sentiment"]["document"]["score"]
# Out:
# -0.809025

# %% [markdown]
# #### Combining results together

# %%
# Create a dataframe from the results
column_names = ["Tweet_Id", "Tweet_Text", "NLU_Sentiment", "NLU_Score"]
nlu_results = [tweet_id, tweet_list, sentiment_list, score_list]
results_dict = dict(zip(column_names,nlu_results))
results = pd.DataFrame.from_dict(results_dict, orient='columns')
results = results[column_names]   # set specific column order

# %%
results.head(10)
# Out:
#        Tweet_Id  \
# 0  9.228920e+17
# 1  9.225192e+17
# 2  9.227325e+17
# 3  9.224475e+17
# 4  9.218857e+17
# 5  9.226445e+17
# 6  9.234497e+17
# 7  9.234124e+17
# 8  9.228903e+17
# 9  9.229562e+17
#
#                                                                                                                                      Tweet_Text  \
# 0            Bob loves a good sunrise. #teamfastncurious #rebellerally #adventure #outdoorwomen #adventure4x4 #offroad… https://t.co/jVWgaumuvo
# 1          FYI: What about gloves, goggles &amp; mask in car? Adam says he bought them to change a rusty part under his old Jeep #ConleyRetrial
# 2  RT @JeepsiesBlog: Baby Jeep stacking! For the win! Love this photo by @Kirby98tj Teach 'em young! #jeepmafia #jeepkids https://t.co/0m9Tuuk…
# 3                  RT @loveysparkz: ZAIN LOOKS SO FREAKING HOT DRIVING THE JEEP!! I CAN'T HANDLE ITT 😍😍😍😭😭😭 #naamkarann https://t.co/wJfCQY73G0
# 4                                   Lovin this GA Jeep Weather!!!    🍂🍁🍂🍁🍂🍁 #welcomefall #fall #jeep #galove #topless 🚙 https://t.co/duP8naJkJr
# 5                                                                                 #JustForYouSweepstakes @sprint I would love to win the Jeep ☺
# 6                                       @sprint Would love to drive a 2018 Jeep Cherokee Overland to the Grand Canyon!!! #JustForYouSweepstakes
# 7                                                                                            Love my Jeep but get tired of replacing 💩 on it. 😒
# 8                                                                            RT @zachkossick: I love my jeep but fucking god is it slow as shit
# 9                                                        I liked a @YouTube video https://t.co/plhSQ4P9RW 10 things we HATE about our SRT8 Jeep
#
#   NLU_Sentiment  NLU_Score
# 0      positive   0.801676
# 1      negative  -0.645835
# 2      positive   0.688216
# 3      negative  -0.445173
# 4       neutral        0.0
# 5       neutral        0.0
# 6      positive   0.456867
# 7      negative  -0.679555
# 8      negative  -0.927686
# 9      negative  -0.809025

# %%
# Data Export
outfile = "jeep_with_sentiment.xlsx"
outpath = directory + outfile

writer = pd.ExcelWriter(outpath, engine = "xlsxwriter")
results.to_excel(writer)
writer.save()
